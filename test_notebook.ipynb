# %%
import spacy
import subprocess

# %%
size='sm'

spacy.util.is_package(f"en_core_web_{size}")
# Out:
# False

# %%
subprocess.run(["python", "-m", "spacy", "download", f"en_core_web_{size}"], check=True)
#!python -m spacy download en_core_web_sm
# Out:
# c:\Users\user\Documents\Projects\kisz-nlp-embeddings\.venv\Scripts\python.exe: No module named pip
