# %% [markdown]
# Embedding models are state-of-the-art for many natural language processing tasks. They are transformer-based models trained using a variant of the transformer’s decoder.
#
# In the ever-evolving domain of Natural Language Processing (NLP), understanding and implementing efficient word embedding models is crucial. This blog post explores some of the leading open-source embedding models like Google’s BERT, Facebook’s RoBERTa, Google Brain’s XLNet, Google’s Electra and T5 etc etc..
#
# Lets delve into how these transformer-based models work, their strengths, and how they can be implemented with code examples.
# BERT (Bidirectional Encoder Representations from Transformers):
#
# Developed by Google, BERT is a transformer-based model like GPT but uses a bidirectional mechanism which makes it powerful for various NLP tasks.
#
# from transformers import BertModel, BertTokenizer
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# model = BertModel.from_pretrained("bert-base-uncased")
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs)
#
# 2. RoBERTa (Robustly optimized BERT approach):
#
# RoBERTa is a variant of BERT that uses dynamic masking rather than static masking. It’s developed by Facebook AI.
#
# from transformers import RobertaTokenizer, RobertaModel
# tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
# model = RobertaModel.from_pretrained('roberta-base')
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs)
#
# 3. XLNet:
#
# XLNet, developed by Google Brain, is a generalized autoregressive pretraining method that enables learning bidirectional contexts by maximizing the expected likelihood over all permutations of the input sequence.
#
# from transformers import XLNetTokenizer, XLNetModel
# tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')
# model = XLNetModel.from_pretrained('xlnet-base-cased')
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs)
#
# 4. Electra:
#
# Electra, developed by Google Research, is a pre-training approach that trains two transformer models: the generator and the discriminator. The generator’s job is to replace tokens in a sentence, and the discriminator’s job is to predict which tokens were replaced by the generator.
#
# from transformers import ElectraTokenizer, ElectraModel
# tokenizer = ElectraTokenizer.from_pretrained('google/electra-small-discriminator')
# model = ElectraModel.from_pretrained('google/electra-small-discriminator')
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs)
#
# 5. T5 (Text-to-Text Transfer Transformer):
#
# T5, developed by Google, is a transformer model that casts all NLP tasks into a text-to-text format. It’s pre-trained on a large corpus and fine-tuned for specific tasks.
#
# from transformers import T5Tokenizer, T5Model
# tokenizer = T5Tokenizer.from_pretrained('t5-base')
# model = T5Model.from_pretrained('t5-base')
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# outputs = model(**inputs)
#
# Please note that the provided code snippets are very basic examples of how to use these models. For real-world tasks, we’ll need to preprocess our data and fine-tune the models according to our specific requirements.
#
# https://medium.com/@pankaj_pandey/exploring-top-open-source-embedding-models-for-semantic-search-a-deep-dive-into-nlp-b5c570e1ce9e
#
# https://www.tensorflow.org/hub/tutorials/semantic_similarity_with_tf_hub_universal_encoder
#
# https://www.graft.com/blog/text-embeddings-for-search-semantic

# %% [markdown]
# ## 2. Choosing the Models
#
# Description
#
#
# ### 2.1. BERT
#
# Description

# %%
from transformers import BertModel, BertTokenizer 
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased') 
model_bert = BertModel.from_pretrained("bert-base-uncased")

# %% [markdown]
# ### 2.2. RoBERTa
#
# Description

# %%
# from transformers import RobertaTokenizer, RobertaModel 
# tokenizer = RobertaTokenizer.from_pretrained('roberta-base') 
# model_roberta = RobertaModel.from_pretrained('roberta-base')

# %% [markdown]
# ### 2.3. XLNet
#
# Description

# %%
# from transformers import XLNetTokenizer, XLNetModel 
# tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased') 
# model_xlnet = XLNetModel.from_pretrained('xlnet-base-cased')

# %% [markdown]
# ### 2.4. Electra
#
# Description

# %%
# from transformers import ElectraTokenizer, ElectraModel 
# tokenizer = ElectraTokenizer.from_pretrained('google/electra-small-discriminator') 
# model_electra = ElectraModel.from_pretrained('google/electra-small-discriminator')

# %% [markdown]
# ### 2.5. T-5
#
# Description

# %%
# from transformers import T5Tokenizer, T5Model 
# tokenizer = T5Tokenizer.from_pretrained('t5-base') 
# model = T5Model.from_pretrained('t5-base')

# %% [markdown]
# ## 3. Creating the embeddings

# %%
inputs = tokenizer("Hello, my dog is cute", return_tensors="pt") 
outputs = model(**inputs)
