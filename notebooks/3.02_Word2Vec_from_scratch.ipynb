# %% [markdown]
# <div style="background-color: #ffffff; color: #000000; padding: 10px;">
# <img src="../media/img/kisz_logo.png" width="192" height="69">
# <h1> Working with embeddings:
# <h2>An introductory workshop with applications on Semantic Search
# </div>

# %% [markdown]
# <div style="background-color: #f6a800; color: #ffffff; padding: 10px;">
# <h2>Part 3.2 - Word2Vec from scratch
# </div>
#
# In this section, we will build a Word2Vec model from scratch, exploring both the Continuous Bag of Words (CBOW) and Skip-gram architectures in detail. Unlike the previous notebook, where we used <kbd>gensim</kbd>, here we will implement the training process manually using NumPy. We will cover data preprocessing, model training, and optimization techniques such as negative sampling. Finally, we will analyze the learned embeddings and evaluate their effectiveness in capturing semantic relationships between words.
#
# We start as usual importing some packages.

# %%
# imports
import sys
import pandas as pd
import numpy as np

from nb_config import INTERIM_DATA_PATH

from src.data import data_loader

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="background-color: #dd6108; color: #ffffff; padding: 10px;">
# <h3>1. Overview
# </div>
#
# We have seen in the last notebook that Word2Vec is a neural network-based approach for learning word embeddings that capture semantic relationships between words. In this notebook, we will implement Word2Vec from scratch, covering both the Continuous Bag of Words (CBOW) and Skip-gram architectures in depth.
#
# Let's talk about this two architectures:
#
# - Continuous Bag of Words (CBOW):
#     - The CBOW model predicts a target word based on a given context (surrounding words).
#     - Given a window of words around the target word, the model learns to predict the target word using these context words.
#     - The model is trained by adjusting the word vectors such that words appearing in similar contexts have similar embeddings.
#     - CBOW is generally faster and works well with smaller datasets but may not capture rare words as effectively as Skip-gram.
#
# - Skip-gram
#   - The Skip-gram model does the reverse of CBOW: it predicts the surrounding words given a target word.
#   - It learns to maximize the probability of correctly predicting context words for a given target word.
#   - Skip-gram is more computationally expensive but performs well on large datasets and captures rare words better than CBOW.
#
# The training process involves the following steps:
#
# - Preparing the Data
#   - Tokenizing text into words and constructing a vocabulary.
#   - Creating training pairs (context-target for CBOW or target-context for Skip-gram).
# - Building the Neural Network
#   - A simple neural network with an input layer, a hidden layer (embedding layer), and an output layer.
#   - The hidden layer learns word embeddings, which are adjusted during training.
# - Training the Model
#   - Using one-hot encoding to represent words in the vocabulary.
#   - Using softmax activation in the output layer to predict the target/context words.
#   - Employing backpropagation and stochastic gradient descent (SGD) to optimize word vectors.
#   - To improve efficiency, negative sampling or hierarchical softmax can be used.
# - Extracting Word Embeddings
#   - Once training is complete, the word vectors from the hidden layer can be used for semantic analysis.
#   - Similar words should have close vector representations in the learned space.
#
# As the way of implementing both architectures is quite similar we will do it at the same time, but taking a bit more of time in the parts that are different.
#
# We are going to need at this point our tokens. Let's load them.

# %%
df, params = data_loader("my_tokenized_data.parquet")

# extract the arguments for the normalize function
tokenizer = params['tokenizer']
arguments = params['args']

# print the tokenizer used getting the tokens
print(f"Tokenizer used: {tokenizer}")
print(f"Arguments passed to the normalize function:\n{arguments}")
# Out:
# Tokenizer used: NLTKTokenizer
# Arguments passed to the normalize function:
# {'lemma': False, 'stop_words': True, 'punct_signs': True, 'stemmer': None, 'case_folding': True}

# %% [markdown]
# <div style="background-color: #dd6108; color: #ffffff; padding: 10px;">
# <h3>2. Preparing the data
# </div>

# %% [markdown]
# We are going to create our vocabulary and associate every token to a specific index. We need to be able to map every token to its index and vice versa.

# %%
# Your code here
vocabulary = ...

# calculate the vocabulary size and print it 
vocab_size = len(vocabulary)
print(f"The vocabulary has {vocab_size} tokens.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 vocabulary = ...
#       4 # calculate the vocabulary size and print it
# ----> 5 vocab_size = len(vocabulary)
#       6 print(f"The vocabulary has {vocab_size} tokens.")
#
# TypeError: object of type 'ellipsis' has no len()

# %%
# SOLUTION

# create an easy access to the tokens
tokens = df['tokens']

# create an empty set
vocabulary = set()

# iterate over the pd Series and updates the set
for index in df.index:
   vocabulary.update(df.loc[index, 'tokens'].tolist())

# turn the vocabulary into a list
vocabulary = list(vocabulary)

# print vocabulary size
vocab_size = len(vocabulary)

print(f"The vocabulary has {vocab_size} tokens.")
# Out:
# The vocabulary has 17093 tokens.

# %% [markdown]
# We are going to create now two mappings for the tokens and their indexes, one for each direction. That will make things much easier

# %%
# Your code here
token_to_idx = ...
idx_to_token = ...

# %%
# SOLUTION
token_to_idx = {token: idx for idx, token in enumerate(vocabulary)}
idx_to_token = {idx: token for token, idx in token_to_idx.items()}

# %% [markdown]
# We need now to create the training pairs.
#
# For that we will create a empty list and will populate it with tuples. Each tuple corresponds to a single training datapoint and is composed of two elements:
# - the central word
# - the context words
#
# In CBoW the context words will be the input and the central word the expected output. In the SkipGram architecture we have the inverse case, the central word as input and the context words as expected ouputs.
#
# We start by formatting our corpus. Our texts have already been tokenized, so we can create a tokenized version of the corpus, where we bring into a list the list of tokens for each film.

# %%
# Your code here

tk_corpus = ...

# define the function
def generate_training_data(corpus, window_size=2):
    ...
    return training_data

training_data = generate_training_data(tk_corpus)

# %%
## SOLUTION

tk_corpus = tokens.tolist()

# define the function
def generate_training_data(corpus, window_size=2):
    training_data = []
    for doc in corpus:
        for i in range(len(doc)):
            context = np.append(doc[max(0, i - window_size):i], doc[i + 1:i + 1 + window_size])
            center = doc[i]
            training_data.append((center, context))
    return training_data

training_data = generate_training_data(tk_corpus)

# %% [markdown]
# We can take a look and see how does it look like:

# %%
training_data
# Out:
# [('led', array(['woody', 'andy'], dtype=object)),
#  ('woody', array(['led', 'andy', "'s"], dtype=object)),
#  ('andy', array(['led', 'woody', "'s", 'toys'], dtype=object)),
#  ("'s", array(['woody', 'andy', 'toys', 'live'], dtype=object)),
#  ('toys', array(['andy', "'s", 'live', 'happily'], dtype=object)),
#  ('live', array(["'s", 'toys', 'happily', 'room'], dtype=object)),
#  ('happily', array(['toys', 'live', 'room', 'andy'], dtype=object)),
#  ('room', array(['live', 'happily', 'andy', "'s"], dtype=object)),
#  ('andy', array(['happily', 'room', "'s", 'birthday'], dtype=object)),
#  ("'s", array(['room', 'andy', 'birthday', 'brings'], dtype=object)),
#  ('birthday', array(['andy', "'s", 'brings', 'buzz'], dtype=object)),
#  ('brings', array(["'s", 'birthday', 'buzz', 'lightyear'], dtype=object)),
#  ('buzz', array(['birthday', 'brings', 'lightyear', 'onto'], dtype=object)),
#  ('lightyear', array(['brings', 'buzz', 'onto', 'scene'], dtype=object)),
#  ('onto', array(['buzz', 'lightyear', 'scene', 'afraid'], dtype=object)),
#  ('scene', array(['lightyear', 'onto', 'afraid', 'losing'], dtype=object)),
#  ('afraid', array(['onto', 'scene', 'losing', 'place'], dtype=object)),
#  ('losing', array(['scene', 'afraid', 'place', 'andy'], dtype=object)),
#  ('place', array(['afraid', 'losing', 'andy', "'s"], dtype=object)),
#  ('andy', array(['losing', 'place', "'s", 'heart'], dtype=object)),
#  ("'s", array(['place', 'andy', 'heart', 'woody'], dtype=object)),
#  ('heart', array(['andy', "'s", 'woody', 'plots'], dtype=object)),
#  ('woody', array(["'s", 'heart', 'plots', 'buzz'], dtype=object)),
#  ('plots', array(['heart', 'woody', 'buzz', 'but'], dtype=object)),
#  ('buzz', array(['woody', 'plots', 'but', 'circumstances'], dtype=object)),
#  ('but', array(['plots', 'buzz', 'circumstances', 'separate'], dtype=object)),
#  ('circumstances', array(['buzz', 'but', 'separate', 'buzz'], dtype=object)),
#  ('separate', array(['but', 'circumstances', 'buzz', 'woody'], dtype=object)),
#  ('buzz',
#   array(['circumstances', 'separate', 'woody', 'owner'], dtype=object)),
#  ('woody', array(['separate', 'buzz', 'owner', 'duo'], dtype=object)),
#  ('owner', array(['buzz', 'woody', 'duo', 'eventually'], dtype=object)),
#  ('duo', array(['woody', 'owner', 'eventually', 'learns'], dtype=object)),
#  ('eventually', array(['owner', 'duo', 'learns', 'put'], dtype=object)),
#  ('learns', array(['duo', 'eventually', 'put', 'aside'], dtype=object)),
#  ('put',
#   array(['eventually', 'learns', 'aside', 'differences'], dtype=object)),
#  ('aside', array(['learns', 'put', 'differences'], dtype=object)),
#  ('differences', array(['put', 'aside'], dtype=object)),
#  ('when', array(['siblings', 'judy'], dtype=object)),
#  ('siblings', array(['when', 'judy', 'peter'], dtype=object)),
#  ('judy', array(['when', 'siblings', 'peter', 'discover'], dtype=object)),
#  ('peter', array(['siblings', 'judy', 'discover', 'enchanted'], dtype=object)),
#  ('discover', array(['judy', 'peter', 'enchanted', 'board'], dtype=object)),
#  ('enchanted', array(['peter', 'discover', 'board', 'game'], dtype=object)),
#  ('board', array(['discover', 'enchanted', 'game', 'opens'], dtype=object)),
#  ('game', array(['enchanted', 'board', 'opens', 'door'], dtype=object)),
#  ('opens', array(['board', 'game', 'door', 'magical'], dtype=object)),
#  ('door', array(['game', 'opens', 'magical', 'world'], dtype=object)),
#  ('magical', array(['opens', 'door', 'world', 'unwittingly'], dtype=object)),
#  ('world', array(['door', 'magical', 'unwittingly', 'invite'], dtype=object)),
#  ('unwittingly', array(['magical', 'world', 'invite', 'alan'], dtype=object)),
#  ('invite', array(['world', 'unwittingly', 'alan', '--'], dtype=object)),
#  ('alan', array(['unwittingly', 'invite', '--', 'adult'], dtype=object)),
#  ('--', array(['invite', 'alan', 'adult', "'s"], dtype=object)),
#  ('adult', array(['alan', '--', "'s", 'trapped'], dtype=object)),
#  ("'s", array(['--', 'adult', 'trapped', 'inside'], dtype=object)),
#  ('trapped', array(['adult', "'s", 'inside', 'game'], dtype=object)),
#  ('inside', array(["'s", 'trapped', 'game', '26'], dtype=object)),
#  ('game', array(['trapped', 'inside', '26', 'years'], dtype=object)),
#  ('26', array(['inside', 'game', 'years', '--'], dtype=object)),
#  ('years', array(['game', '26', '--', 'living'], dtype=object)),
#  ('--', array(['26', 'years', 'living', 'room'], dtype=object)),
#  ('living', array(['years', '--', 'room', 'alan'], dtype=object)),
#  ('room', array(['--', 'living', 'alan', "'s"], dtype=object)),
#  ('alan', array(['living', 'room', "'s", 'hope'], dtype=object)),
#  ("'s", array(['room', 'alan', 'hope', 'freedom'], dtype=object)),
#  ('hope', array(['alan', "'s", 'freedom', 'finish'], dtype=object)),
#  ('freedom', array(["'s", 'hope', 'finish', 'game'], dtype=object)),
#  ('finish', array(['hope', 'freedom', 'game', 'proves'], dtype=object)),
#  ('game', array(['freedom', 'finish', 'proves', 'risky'], dtype=object)),
#  ('proves', array(['finish', 'game', 'risky', 'three'], dtype=object)),
#  ('risky', array(['game', 'proves', 'three', 'find'], dtype=object)),
#  ('three', array(['proves', 'risky', 'find', 'running'], dtype=object)),
#  ('find', array(['risky', 'three', 'running', 'giant'], dtype=object)),
#  ('running', array(['three', 'find', 'giant', 'rhinoceroses'], dtype=object)),
#  ('giant', array(['find', 'running', 'rhinoceroses', 'evil'], dtype=object)),
#  ('rhinoceroses',
#   array(['running', 'giant', 'evil', 'monkeys'], dtype=object)),
#  ('evil',
#   array(['giant', 'rhinoceroses', 'monkeys', 'terrifying'], dtype=object)),
#  ('monkeys',
#   array(['rhinoceroses', 'evil', 'terrifying', 'creatures'], dtype=object)),
#  ('terrifying', array(['evil', 'monkeys', 'creatures'], dtype=object)),
#  ('creatures', array(['monkeys', 'terrifying'], dtype=object)),
#  ('obsessive', array(['master', 'thief'], dtype=object)),
#  ('master', array(['obsessive', 'thief', 'neil'], dtype=object)),
#  ('thief', array(['obsessive', 'master', 'neil', 'mccauley'], dtype=object)),
#  ('neil', array(['master', 'thief', 'mccauley', 'leads'], dtype=object)),
#  ('mccauley', array(['thief', 'neil', 'leads', 'top-notch'], dtype=object)),
#  ('leads', array(['neil', 'mccauley', 'top-notch', 'crew'], dtype=object)),
#  ('top-notch', array(['mccauley', 'leads', 'crew', 'various'], dtype=object)),
#  ('crew', array(['leads', 'top-notch', 'various', 'insane'], dtype=object)),
#  ('various', array(['top-notch', 'crew', 'insane', 'heists'], dtype=object)),
#  ('insane', array(['crew', 'various', 'heists', 'throughout'], dtype=object)),
#  ('heists', array(['various', 'insane', 'throughout', 'los'], dtype=object)),
#  ('throughout', array(['insane', 'heists', 'los', 'angeles'], dtype=object)),
#  ('los', array(['heists', 'throughout', 'angeles', 'mentally'], dtype=object)),
#  ('angeles',
#   array(['throughout', 'los', 'mentally', 'unstable'], dtype=object)),
#  ('mentally',
#   array(['los', 'angeles', 'unstable', 'detective'], dtype=object)),
#  ('unstable',
#   array(['angeles', 'mentally', 'detective', 'vincent'], dtype=object)),
#  ('detective',
#   array(['mentally', 'unstable', 'vincent', 'hanna'], dtype=object)),
#  ('vincent',
#   array(['unstable', 'detective', 'hanna', 'pursues'], dtype=object)),
#  ('hanna',
#   array(['detective', 'vincent', 'pursues', 'without'], dtype=object)),
#  ('pursues', array(['vincent', 'hanna', 'without', 'rest'], dtype=object)),
#  ('without', array(['hanna', 'pursues', 'rest', 'each'], dtype=object)),
#  ('rest', array(['pursues', 'without', 'each', 'man'], dtype=object)),
#  ('each', array(['without', 'rest', 'man', 'recognizes'], dtype=object)),
#  ('man', array(['rest', 'each', 'recognizes', 'respects'], dtype=object)),
#  ('recognizes', array(['each', 'man', 'respects', 'ability'], dtype=object)),
#  ('respects',
#   array(['man', 'recognizes', 'ability', 'dedication'], dtype=object)),
#  ('ability',
#   array(['recognizes', 'respects', 'dedication', 'even'], dtype=object)),
#  ('dedication',
#   array(['respects', 'ability', 'even', 'though'], dtype=object)),
#  ('even', array(['ability', 'dedication', 'though', 'aware'], dtype=object)),
#  ('though',
#   array(['dedication', 'even', 'aware', 'cat-and-mouse'], dtype=object)),
#  ('aware', array(['even', 'though', 'cat-and-mouse', 'game'], dtype=object)),
#  ('cat-and-mouse', array(['though', 'aware', 'game', 'may'], dtype=object)),
#  ('game', array(['aware', 'cat-and-mouse', 'may', 'end'], dtype=object)),
#  ('may', array(['cat-and-mouse', 'game', 'end', 'violence'], dtype=object)),
#  ('end', array(['game', 'may', 'violence'], dtype=object)),
#  ('violence', array(['may', 'end'], dtype=object)),
#  ('james', array(['bond', 'must'], dtype=object)),
#  ('bond', array(['james', 'must', 'unmask'], dtype=object)),
#  ('must', array(['james', 'bond', 'unmask', 'mysterious'], dtype=object)),
#  ('unmask', array(['bond', 'must', 'mysterious', 'head'], dtype=object)),
#  ('mysterious', array(['must', 'unmask', 'head', 'janus'], dtype=object)),
#  ('head', array(['unmask', 'mysterious', 'janus', 'syndicate'], dtype=object)),
#  ('janus',
#   array(['mysterious', 'head', 'syndicate', 'prevent'], dtype=object)),
#  ('syndicate', array(['head', 'janus', 'prevent', 'leader'], dtype=object)),
#  ('prevent',
#   array(['janus', 'syndicate', 'leader', 'utilizing'], dtype=object)),
#  ('leader',
#   array(['syndicate', 'prevent', 'utilizing', 'goldeneye'], dtype=object)),
#  ('utilizing',
#   array(['prevent', 'leader', 'goldeneye', 'weapons'], dtype=object)),
#  ('goldeneye',
#   array(['leader', 'utilizing', 'weapons', 'system'], dtype=object)),
#  ('weapons',
#   array(['utilizing', 'goldeneye', 'system', 'inflict'], dtype=object)),
#  ('system',
#   array(['goldeneye', 'weapons', 'inflict', 'devastating'], dtype=object)),
#  ('inflict',
#   array(['weapons', 'system', 'devastating', 'revenge'], dtype=object)),
#  ('devastating',
#   array(['system', 'inflict', 'revenge', 'britain'], dtype=object)),
#  ('revenge', array(['inflict', 'devastating', 'britain'], dtype=object)),
#  ('britain', array(['devastating', 'revenge'], dtype=object)),
#  ('widowed', array(['u.s.', 'president'], dtype=object)),
#  ('u.s.', array(['widowed', 'president', 'andrew'], dtype=object)),
#  ('president', array(['widowed', 'u.s.', 'andrew', 'shepherd'], dtype=object)),
#  ('andrew', array(['u.s.', 'president', 'shepherd', 'one'], dtype=object)),
#  ('shepherd', array(['president', 'andrew', 'one', 'world'], dtype=object)),
#  ('one', array(['andrew', 'shepherd', 'world', "'s"], dtype=object)),
#  ('world', array(['shepherd', 'one', "'s", 'powerful'], dtype=object)),
#  ("'s", array(['one', 'world', 'powerful', 'men'], dtype=object)),
#  ('powerful', array(['world', "'s", 'men', 'anything'], dtype=object)),
#  ('men', array(["'s", 'powerful', 'anything', 'wants'], dtype=object)),
#  ('anything', array(['powerful', 'men', 'wants', '--'], dtype=object)),
#  ('wants', array(['men', 'anything', '--', 'covets'], dtype=object)),
#  ('--', array(['anything', 'wants', 'covets', 'sydney'], dtype=object)),
#  ('covets', array(['wants', '--', 'sydney', 'ellen'], dtype=object)),
#  ('sydney', array(['--', 'covets', 'ellen', 'wade'], dtype=object)),
#  ('ellen', array(['covets', 'sydney', 'wade', 'washington'], dtype=object)),
#  ('wade', array(['sydney', 'ellen', 'washington', 'lobbyist'], dtype=object)),
#  ('washington', array(['ellen', 'wade', 'lobbyist', 'but'], dtype=object)),
#  ('lobbyist', array(['wade', 'washington', 'but', 'shepherd'], dtype=object)),
#  ('but', array(['washington', 'lobbyist', 'shepherd', "'s"], dtype=object)),
#  ('shepherd', array(['lobbyist', 'but', "'s", 'attempts'], dtype=object)),
#  ("'s", array(['but', 'shepherd', 'attempts', 'courting'], dtype=object)),
#  ('attempts', array(['shepherd', "'s", 'courting', 'spark'], dtype=object)),
#  ('courting', array(["'s", 'attempts', 'spark', 'wild'], dtype=object)),
#  ('spark', array(['attempts', 'courting', 'wild', 'rumors'], dtype=object)),
#  ('wild', array(['courting', 'spark', 'rumors', 'decimate'], dtype=object)),
#  ('rumors', array(['spark', 'wild', 'decimate', 'approval'], dtype=object)),
#  ('decimate', array(['wild', 'rumors', 'approval', 'ratings'], dtype=object)),
#  ('approval', array(['rumors', 'decimate', 'ratings'], dtype=object)),
#  ('ratings', array(['decimate', 'approval'], dtype=object)),
#  ('an', array(['outcast', 'half-wolf'], dtype=object)),
#  ('outcast', array(['an', 'half-wolf', 'risks'], dtype=object)),
#  ('half-wolf', array(['an', 'outcast', 'risks', 'life'], dtype=object)),
#  ('risks', array(['outcast', 'half-wolf', 'life', 'prevent'], dtype=object)),
#  ('life', array(['half-wolf', 'risks', 'prevent', 'deadly'], dtype=object)),
#  ('prevent', array(['risks', 'life', 'deadly', 'epidemic'], dtype=object)),
#  ('deadly', array(['life', 'prevent', 'epidemic', 'ravaging'], dtype=object)),
#  ('epidemic', array(['prevent', 'deadly', 'ravaging', 'nome'], dtype=object)),
#  ('ravaging', array(['deadly', 'epidemic', 'nome', 'alaska'], dtype=object)),
#  ('nome', array(['epidemic', 'ravaging', 'alaska'], dtype=object)),
#  ('alaska', array(['ravaging', 'nome'], dtype=object)),
#  ('the', array(['life', 'gambling'], dtype=object)),
#  ('life', array(['the', 'gambling', 'paradise'], dtype=object)),
#  ('gambling', array(['the', 'life', 'paradise', '–'], dtype=object)),
#  ('paradise', array(['life', 'gambling', '–', 'las'], dtype=object)),
#  ('–', array(['gambling', 'paradise', 'las', 'vegas'], dtype=object)),
#  ('las', array(['paradise', '–', 'vegas', '–'], dtype=object)),
#  ('vegas', array(['–', 'las', '–', 'dark'], dtype=object)),
#  ('–', array(['las', 'vegas', 'dark', 'mafia'], dtype=object)),
#  ('dark', array(['vegas', '–', 'mafia', 'underbelly'], dtype=object)),
#  ('mafia', array(['–', 'dark', 'underbelly'], dtype=object)),
#  ('underbelly', array(['dark', 'mafia'], dtype=object)),
#  ('rich', array(['mr.', 'dashwood'], dtype=object)),
#  ('mr.', array(['rich', 'dashwood', 'dies'], dtype=object)),
#  ('dashwood', array(['rich', 'mr.', 'dies', 'leaving'], dtype=object)),
#  ('dies', array(['mr.', 'dashwood', 'leaving', 'second'], dtype=object)),
#  ('leaving', array(['dashwood', 'dies', 'second', 'wife'], dtype=object)),
#  ('second', array(['dies', 'leaving', 'wife', 'daughters'], dtype=object)),
#  ('wife', array(['leaving', 'second', 'daughters', 'poor'], dtype=object)),
#  ('daughters', array(['second', 'wife', 'poor', 'rules'], dtype=object)),
#  ('poor', array(['wife', 'daughters', 'rules', 'inheritance'], dtype=object)),
#  ('rules', array(['daughters', 'poor', 'inheritance', 'two'], dtype=object)),
#  ('inheritance', array(['poor', 'rules', 'two', 'daughters'], dtype=object)),
#  ('two',
#   array(['rules', 'inheritance', 'daughters', 'titular'], dtype=object)),
#  ('daughters',
#   array(['inheritance', 'two', 'titular', 'opposites'], dtype=object)),
#  ('titular', array(['two', 'daughters', 'opposites'], dtype=object)),
#  ('opposites', array(['daughters', 'titular'], dtype=object)),
#  ('it', array(["'s", 'ted'], dtype=object)),
#  ("'s", array(['it', 'ted', 'bellhop'], dtype=object)),
#  ('ted', array(['it', "'s", 'bellhop', "'s"], dtype=object)),
#  ('bellhop', array(["'s", 'ted', "'s", 'first'], dtype=object)),
#  ("'s", array(['ted', 'bellhop', 'first', 'night'], dtype=object)),
#  ('first', array(['bellhop', "'s", 'night', 'job'], dtype=object)),
#  ('night', array(["'s", 'first', 'job', '...'], dtype=object)),
#  ('job', array(['first', 'night', '...', 'hotel'], dtype=object)),
#  ('...', array(['night', 'job', 'hotel', "'s"], dtype=object)),
#  ('hotel', array(['job', '...', "'s", 'unusual'], dtype=object)),
#  ("'s", array(['...', 'hotel', 'unusual', 'guests'], dtype=object)),
#  ('unusual', array(['hotel', "'s", 'guests', 'place'], dtype=object)),
#  ('guests', array(["'s", 'unusual', 'place', 'outrageous'], dtype=object)),
#  ('place',
#   array(['unusual', 'guests', 'outrageous', 'predicaments'], dtype=object)),
#  ('outrageous',
#   array(['guests', 'place', 'predicaments', 'it'], dtype=object)),
#  ('predicaments', array(['place', 'outrageous', 'it', 'seems'], dtype=object)),
#  ('it',
#   array(['outrageous', 'predicaments', 'seems', 'evening'], dtype=object)),
#  ('seems', array(['predicaments', 'it', 'evening', "'s"], dtype=object)),
#  ('evening', array(['it', 'seems', "'s", 'room'], dtype=object)),
#  ("'s", array(['seems', 'evening', 'room', 'service'], dtype=object)),
#  ('room', array(['evening', "'s", 'service', 'serving'], dtype=object)),
#  ('service', array(["'s", 'room', 'serving', 'one'], dtype=object)),
#  ('serving', array(['room', 'service', 'one', 'unbelievable'], dtype=object)),
#  ('one',
#   array(['service', 'serving', 'unbelievable', 'happening'], dtype=object)),
#  ('unbelievable',
#   array(['serving', 'one', 'happening', 'another'], dtype=object)),
#  ('happening', array(['one', 'unbelievable', 'another'], dtype=object)),
#  ('another', array(['unbelievable', 'happening'], dtype=object)),
#  ('summoned', array(['ashram', 'tibet'], dtype=object)),
#  ('ashram', array(['summoned', 'tibet', 'ace'], dtype=object)),
#  ('tibet', array(['summoned', 'ashram', 'ace', 'finds'], dtype=object)),
#  ('ace', array(['ashram', 'tibet', 'finds', 'perilous'], dtype=object)),
#  ('finds', array(['tibet', 'ace', 'perilous', 'journey'], dtype=object)),
#  ('perilous', array(['ace', 'finds', 'journey', 'jungles'], dtype=object)),
#  ('journey', array(['finds', 'perilous', 'jungles', 'africa'], dtype=object)),
#  ('jungles', array(['perilous', 'journey', 'africa', 'find'], dtype=object)),
#  ('africa', array(['journey', 'jungles', 'find', 'shikaka'], dtype=object)),
#  ('find', array(['jungles', 'africa', 'shikaka', 'missing'], dtype=object)),
#  ('shikaka', array(['africa', 'find', 'missing', 'sacred'], dtype=object)),
#  ('missing', array(['find', 'shikaka', 'sacred', 'animal'], dtype=object)),
#  ('sacred', array(['shikaka', 'missing', 'animal', 'friendly'], dtype=object)),
#  ('animal', array(['missing', 'sacred', 'friendly', 'wachati'], dtype=object)),
#  ('friendly', array(['sacred', 'animal', 'wachati', 'tribe'], dtype=object)),
#  ('wachati', array(['animal', 'friendly', 'tribe', 'he'], dtype=object)),
#  ('tribe', array(['friendly', 'wachati', 'he', 'must'], dtype=object)),
#  ('he', array(['wachati', 'tribe', 'must', 'accomplish'], dtype=object)),
#  ('must', array(['tribe', 'he', 'accomplish', 'wedding'], dtype=object)),
#  ('accomplish', array(['he', 'must', 'wedding', 'wachati'], dtype=object)),
#  ('wedding', array(['must', 'accomplish', 'wachati', "'s"], dtype=object)),
#  ('wachati', array(['accomplish', 'wedding', "'s", 'princess'], dtype=object)),
#  ("'s", array(['wedding', 'wachati', 'princess', 'prince'], dtype=object)),
#  ('princess', array(['wachati', "'s", 'prince', 'warrior'], dtype=object)),
#  ('prince', array(["'s", 'princess', 'warrior', 'wachootoos'], dtype=object)),
#  ('warrior', array(['princess', 'prince', 'wachootoos', 'if'], dtype=object)),
#  ('wachootoos', array(['prince', 'warrior', 'if', 'ace'], dtype=object)),
#  ('if', array(['warrior', 'wachootoos', 'ace', 'fails'], dtype=object)),
#  ('ace', array(['wachootoos', 'if', 'fails', 'result'], dtype=object)),
#  ('fails', array(['if', 'ace', 'result', 'vicious'], dtype=object)),
#  ('result', array(['ace', 'fails', 'vicious', 'tribal'], dtype=object)),
#  ('vicious', array(['fails', 'result', 'tribal', 'war'], dtype=object)),
#  ('tribal', array(['result', 'vicious', 'war'], dtype=object)),
#  ('war', array(['vicious', 'tribal'], dtype=object)),
#  ('chili', array(['palmer', 'miami'], dtype=object)),
#  ('palmer', array(['chili', 'miami', 'mobster'], dtype=object)),
#  ('miami', array(['chili', 'palmer', 'mobster', 'gets'], dtype=object)),
#  ('mobster', array(['palmer', 'miami', 'gets', 'sent'], dtype=object)),
#  ('gets', array(['miami', 'mobster', 'sent', 'boss'], dtype=object)),
#  ('sent', array(['mobster', 'gets', 'boss', 'psychopathic'], dtype=object)),
#  ('boss', array(['gets', 'sent', 'psychopathic', '``'], dtype=object)),
#  ('psychopathic', array(['sent', 'boss', '``', 'bones'], dtype=object)),
#  ('``', array(['boss', 'psychopathic', 'bones', 'barboni'], dtype=object)),
#  ('bones', array(['psychopathic', '``', 'barboni', 'collect'], dtype=object)),
#  ('barboni', array(['``', 'bones', 'collect', 'bad'], dtype=object)),
#  ('collect', array(['bones', 'barboni', 'bad', 'debt'], dtype=object)),
#  ('bad', array(['barboni', 'collect', 'debt', 'harry'], dtype=object)),
#  ('debt', array(['collect', 'bad', 'harry', 'zimm'], dtype=object)),
#  ('harry', array(['bad', 'debt', 'zimm', 'hollywood'], dtype=object)),
#  ('zimm', array(['debt', 'harry', 'hollywood', 'producer'], dtype=object)),
#  ('hollywood',
#   array(['harry', 'zimm', 'producer', 'specializes'], dtype=object)),
#  ('producer',
#   array(['zimm', 'hollywood', 'specializes', 'cheesy'], dtype=object)),
#  ('specializes',
#   array(['hollywood', 'producer', 'cheesy', 'horror'], dtype=object)),
#  ('cheesy',
#   array(['producer', 'specializes', 'horror', 'films'], dtype=object)),
#  ('horror', array(['specializes', 'cheesy', 'films', 'when'], dtype=object)),
#  ('films', array(['cheesy', 'horror', 'when', 'chili'], dtype=object)),
#  ('when', array(['horror', 'films', 'chili', 'meets'], dtype=object)),
#  ('chili', array(['films', 'when', 'meets', 'harry'], dtype=object)),
#  ('meets', array(['when', 'chili', 'harry', "'s"], dtype=object)),
#  ('harry', array(['chili', 'meets', "'s", 'leading'], dtype=object)),
#  ("'s", array(['meets', 'harry', 'leading', 'lady'], dtype=object)),
#  ('leading', array(['harry', "'s", 'lady', 'romantic'], dtype=object)),
#  ('lady', array(["'s", 'leading', 'romantic', 'sparks'], dtype=object)),
#  ('romantic', array(['leading', 'lady', 'sparks', 'fly'], dtype=object)),
#  ('sparks', array(['lady', 'romantic', 'fly', 'after'], dtype=object)),
#  ('fly', array(['romantic', 'sparks', 'after', 'pitching'], dtype=object)),
#  ('after', array(['sparks', 'fly', 'pitching', 'life'], dtype=object)),
#  ('pitching', array(['fly', 'after', 'life', 'story'], dtype=object)),
#  ('life', array(['after', 'pitching', 'story', 'movie'], dtype=object)),
#  ('story', array(['pitching', 'life', 'movie', 'idea'], dtype=object)),
#  ('movie', array(['life', 'story', 'idea', 'chili'], dtype=object)),
#  ('idea', array(['story', 'movie', 'chili', 'learns'], dtype=object)),
#  ('chili', array(['movie', 'idea', 'learns', 'mobster'], dtype=object)),
#  ('learns', array(['idea', 'chili', 'mobster', 'hollywood'], dtype=object)),
#  ('mobster',
#   array(['chili', 'learns', 'hollywood', 'producer'], dtype=object)),
#  ('hollywood',
#   array(['learns', 'mobster', 'producer', 'really'], dtype=object)),
#  ('producer', array(['mobster', 'hollywood', 'really', "n't"], dtype=object)),
#  ('really',
#   array(['hollywood', 'producer', "n't", 'different'], dtype=object)),
#  ("n't", array(['producer', 'really', 'different'], dtype=object)),
#  ('different', array(['really', "n't"], dtype=object)),
#  ('assassin', array(['robert', 'rath'], dtype=object)),
#  ('robert', array(['assassin', 'rath', 'arrives'], dtype=object)),
#  ('rath', array(['assassin', 'robert', 'arrives', 'funeral'], dtype=object)),
#  ('arrives', array(['robert', 'rath', 'funeral', 'kill'], dtype=object)),
#  ('funeral', array(['rath', 'arrives', 'kill', 'prominent'], dtype=object)),
#  ('kill', array(['arrives', 'funeral', 'prominent', 'mobster'], dtype=object)),
#  ('prominent', array(['funeral', 'kill', 'mobster', 'witness'], dtype=object)),
#  ('mobster', array(['kill', 'prominent', 'witness', 'rival'], dtype=object)),
#  ('witness', array(['prominent', 'mobster', 'rival', 'hired'], dtype=object)),
#  ('rival', array(['mobster', 'witness', 'hired', 'gun'], dtype=object)),
#  ('hired', array(['witness', 'rival', 'gun', 'complete'], dtype=object)),
#  ('gun', array(['rival', 'hired', 'complete', 'job'], dtype=object)),
#  ('complete', array(['hired', 'gun', 'job', '--'], dtype=object)),
#  ('job', array(['gun', 'complete', '--', 'grisly'], dtype=object)),
#  ('--', array(['complete', 'job', 'grisly', 'results'], dtype=object)),
#  ('grisly', array(['job', '--', 'results', 'horrified'], dtype=object)),
#  ('results', array(['--', 'grisly', 'horrified', 'murder'], dtype=object)),
#  ('horrified',
#   array(['grisly', 'results', 'murder', 'innocent'], dtype=object)),
#  ('murder',
#   array(['results', 'horrified', 'innocent', 'bystanders'], dtype=object)),
#  ('innocent',
#   array(['horrified', 'murder', 'bystanders', 'rath'], dtype=object)),
#  ('bystanders',
#   array(['murder', 'innocent', 'rath', 'decides'], dtype=object)),
#  ('rath', array(['innocent', 'bystanders', 'decides', 'take'], dtype=object)),
#  ('decides', array(['bystanders', 'rath', 'take', 'one'], dtype=object)),
#  ('take', array(['rath', 'decides', 'one', 'last'], dtype=object)),
#  ('one', array(['decides', 'take', 'last', 'job'], dtype=object)),
#  ('last', array(['take', 'one', 'job', 'return'], dtype=object)),
#  ('job', array(['one', 'last', 'return', 'civilian'], dtype=object)),
#  ('return', array(['last', 'job', 'civilian', 'life'], dtype=object)),
#  ('civilian', array(['job', 'return', 'life', 'but'], dtype=object)),
#  ('life', array(['return', 'civilian', 'but', 'finding'], dtype=object)),
#  ('but', array(['civilian', 'life', 'finding', 'way'], dtype=object)),
#  ('finding', array(['life', 'but', 'way', 'world'], dtype=object)),
#  ('way', array(['but', 'finding', 'world', 'contract'], dtype=object)),
#  ('world', array(['finding', 'way', 'contract', 'killing'], dtype=object)),
#  ('contract', array(['way', 'world', 'killing', 'grows'], dtype=object)),
#  ('killing', array(['world', 'contract', 'grows', 'ever'], dtype=object)),
#  ('grows', array(['contract', 'killing', 'ever', 'dangerous'], dtype=object)),
#  ('ever', array(['killing', 'grows', 'dangerous', 'rath'], dtype=object)),
#  ('dangerous', array(['grows', 'ever', 'rath', 'falls'], dtype=object)),
#  ('rath', array(['ever', 'dangerous', 'falls', 'female'], dtype=object)),
#  ('falls', array(['dangerous', 'rath', 'female', 'target'], dtype=object)),
#  ('female', array(['rath', 'falls', 'target', 'becomes'], dtype=object)),
#  ('target', array(['falls', 'female', 'becomes', 'marked'], dtype=object)),
#  ('becomes', array(['female', 'target', 'marked', 'man'], dtype=object)),
#  ('marked', array(['target', 'becomes', 'man'], dtype=object)),
#  ('man', array(['becomes', 'marked'], dtype=object)),
#  ('ben', array(['sanderson', 'alcoholic'], dtype=object)),
#  ('sanderson', array(['ben', 'alcoholic', 'hollywood'], dtype=object)),
#  ('alcoholic',
#   array(['ben', 'sanderson', 'hollywood', 'screenwriter'], dtype=object)),
#  ('hollywood',
#   array(['sanderson', 'alcoholic', 'screenwriter', 'lost'], dtype=object)),
#  ('screenwriter',
#   array(['alcoholic', 'hollywood', 'lost', 'everything'], dtype=object)),
#  ('lost',
#   array(['hollywood', 'screenwriter', 'everything', 'drinking'],
#         dtype=object)),
#  ('everything',
#   array(['screenwriter', 'lost', 'drinking', 'arrives'], dtype=object)),
#  ('drinking', array(['lost', 'everything', 'arrives', 'las'], dtype=object)),
#  ('arrives', array(['everything', 'drinking', 'las', 'vegas'], dtype=object)),
#  ('las', array(['drinking', 'arrives', 'vegas', 'drink'], dtype=object)),
#  ('vegas', array(['arrives', 'las', 'drink', 'death'], dtype=object)),
#  ('drink', array(['las', 'vegas', 'death', 'there'], dtype=object)),
#  ('death', array(['vegas', 'drink', 'there', 'meets'], dtype=object)),
#  ('there', array(['drink', 'death', 'meets', 'forms'], dtype=object)),
#  ('meets', array(['death', 'there', 'forms', 'uneasy'], dtype=object)),
#  ('forms', array(['there', 'meets', 'uneasy', 'friendship'], dtype=object)),
#  ('uneasy',
#   array(['meets', 'forms', 'friendship', 'non-interference'], dtype=object)),
#  ('friendship',
#   array(['forms', 'uneasy', 'non-interference', 'pact'], dtype=object)),
#  ('non-interference',
#   array(['uneasy', 'friendship', 'pact', 'prostitute'], dtype=object)),
#  ('pact',
#   array(['friendship', 'non-interference', 'prostitute', 'sera'],
#         dtype=object)),
#  ('prostitute', array(['non-interference', 'pact', 'sera'], dtype=object)),
#  ('sera', array(['pact', 'prostitute'], dtype=object)),
#  ('former', array(['marine', 'louanne'], dtype=object)),
#  ('marine', array(['former', 'louanne', 'johnson'], dtype=object)),
#  ('louanne', array(['former', 'marine', 'johnson', 'lands'], dtype=object)),
#  ('johnson', array(['marine', 'louanne', 'lands', 'gig'], dtype=object)),
#  ('lands', array(['louanne', 'johnson', 'gig', 'teaching'], dtype=object)),
#  ('gig', array(['johnson', 'lands', 'teaching', 'pilot'], dtype=object)),
#  ('teaching', array(['lands', 'gig', 'pilot', 'program'], dtype=object)),
#  ('pilot', array(['gig', 'teaching', 'program', 'bright'], dtype=object)),
#  ('program',
#   array(['teaching', 'pilot', 'bright', 'underachieving'], dtype=object)),
#  ('bright',
#   array(['pilot', 'program', 'underachieving', 'teens'], dtype=object)),
#  ('underachieving',
#   array(['program', 'bright', 'teens', 'notorious'], dtype=object)),
#  ('teens',
#   array(['bright', 'underachieving', 'notorious', 'inner-city'],
#         dtype=object)),
#  ('notorious',
#   array(['underachieving', 'teens', 'inner-city', 'high'], dtype=object)),
#  ('inner-city', array(['teens', 'notorious', 'high', 'school'], dtype=object)),
#  ('high', array(['notorious', 'inner-city', 'school', 'after'], dtype=object)),
#  ('school', array(['inner-city', 'high', 'after', 'terrible'], dtype=object)),
#  ('after', array(['high', 'school', 'terrible', 'first'], dtype=object)),
#  ('terrible', array(['school', 'after', 'first', 'day'], dtype=object)),
#  ('first', array(['after', 'terrible', 'day', 'decides'], dtype=object)),
#  ('day', array(['terrible', 'first', 'decides', 'must'], dtype=object)),
#  ('decides', array(['first', 'day', 'must', 'throw'], dtype=object)),
#  ('must', array(['day', 'decides', 'throw', 'decorum'], dtype=object)),
#  ('throw', array(['decides', 'must', 'decorum', 'wind'], dtype=object)),
#  ('decorum', array(['must', 'throw', 'wind', 'when'], dtype=object)),
#  ('wind', array(['throw', 'decorum', 'when', 'johnson'], dtype=object)),
#  ('when', array(['decorum', 'wind', 'johnson', 'returns'], dtype=object)),
#  ('johnson', array(['wind', 'when', 'returns', 'classroom'], dtype=object)),
#  ('returns', array(['when', 'johnson', 'classroom', 'armed'], dtype=object)),
#  ('classroom',
#   array(['johnson', 'returns', 'armed', 'no-nonsense'], dtype=object)),
#  ('armed',
#   array(['returns', 'classroom', 'no-nonsense', 'attitude'], dtype=object)),
#  ('no-nonsense',
#   array(['classroom', 'armed', 'attitude', 'informed'], dtype=object)),
#  ('attitude',
#   array(['armed', 'no-nonsense', 'informed', 'military'], dtype=object)),
#  ('informed',
#   array(['no-nonsense', 'attitude', 'military', 'training'], dtype=object)),
#  ('military',
#   array(['attitude', 'informed', 'training', 'fearless'], dtype=object)),
#  ('training',
#   array(['informed', 'military', 'fearless', 'determination'], dtype=object)),
#  ('fearless',
#   array(['military', 'training', 'determination', 'better'], dtype=object)),
#  ('determination',
#   array(['training', 'fearless', 'better', 'lives'], dtype=object)),
#  ('better',
#   array(['fearless', 'determination', 'lives', 'students'], dtype=object)),
#  ('lives', array(['determination', 'better', 'students', '--'], dtype=object)),
#  ('students', array(['better', 'lives', '--', 'matter'], dtype=object)),
#  ('--', array(['lives', 'students', 'matter', 'cost'], dtype=object)),
#  ('matter', array(['students', '--', 'cost'], dtype=object)),
#  ('cost', array(['--', 'matter'], dtype=object)),
#  ('in', array(['year', '2035'], dtype=object)),
#  ('year', array(['in', '2035', 'convict'], dtype=object)),
#  ('2035', array(['in', 'year', 'convict', 'james'], dtype=object)),
#  ('convict', array(['year', '2035', 'james', 'cole'], dtype=object)),
#  ('james', array(['2035', 'convict', 'cole', 'reluctantly'], dtype=object)),
#  ('cole',
#   array(['convict', 'james', 'reluctantly', 'volunteers'], dtype=object)),
#  ('reluctantly', array(['james', 'cole', 'volunteers', 'sent'], dtype=object)),
#  ('volunteers', array(['cole', 'reluctantly', 'sent', 'back'], dtype=object)),
#  ('sent', array(['reluctantly', 'volunteers', 'back', 'time'], dtype=object)),
#  ('back', array(['volunteers', 'sent', 'time', 'discover'], dtype=object)),
#  ('time', array(['sent', 'back', 'discover', 'origin'], dtype=object)),
#  ('discover', array(['back', 'time', 'origin', 'deadly'], dtype=object)),
#  ('origin', array(['time', 'discover', 'deadly', 'virus'], dtype=object)),
#  ('deadly', array(['discover', 'origin', 'virus', 'wiped'], dtype=object)),
#  ('virus', array(['origin', 'deadly', 'wiped', 'nearly'], dtype=object)),
#  ('wiped', array(['deadly', 'virus', 'nearly', 'earth'], dtype=object)),
#  ('nearly', array(['virus', 'wiped', 'earth', "'s"], dtype=object)),
#  ('earth', array(['wiped', 'nearly', "'s", 'population'], dtype=object)),
#  ("'s", array(['nearly', 'earth', 'population', 'forced'], dtype=object)),
#  ('population', array(['earth', "'s", 'forced', 'survivors'], dtype=object)),
#  ('forced',
#   array(["'s", 'population', 'survivors', 'underground'], dtype=object)),
#  ('survivors',
#   array(['population', 'forced', 'underground', 'communities'], dtype=object)),
#  ('underground',
#   array(['forced', 'survivors', 'communities', 'but'], dtype=object)),
#  ('communities',
#   array(['survivors', 'underground', 'but', 'cole'], dtype=object)),
#  ('but',
#   array(['underground', 'communities', 'cole', 'mistakenly'], dtype=object)),
#  ('cole', array(['communities', 'but', 'mistakenly', 'sent'], dtype=object)),
#  ('mistakenly', array(['but', 'cole', 'sent', '1990'], dtype=object)),
#  ('sent', array(['cole', 'mistakenly', '1990', 'instead'], dtype=object)),
#  ('1990', array(['mistakenly', 'sent', 'instead', '1996'], dtype=object)),
#  ('instead', array(['sent', '1990', '1996', "'s"], dtype=object)),
#  ('1996', array(['1990', 'instead', "'s", 'arrested'], dtype=object)),
#  ("'s", array(['instead', '1996', 'arrested', 'locked'], dtype=object)),
#  ('arrested', array(['1996', "'s", 'locked', 'mental'], dtype=object)),
#  ('locked', array(["'s", 'arrested', 'mental', 'hospital'], dtype=object)),
#  ('mental', array(['arrested', 'locked', 'hospital', 'there'], dtype=object)),
#  ('hospital', array(['locked', 'mental', 'there', 'meets'], dtype=object)),
#  ('there',
#   array(['mental', 'hospital', 'meets', 'psychiatrist'], dtype=object)),
#  ('meets', array(['hospital', 'there', 'psychiatrist', 'dr.'], dtype=object)),
#  ('psychiatrist', array(['there', 'meets', 'dr.', 'kathryn'], dtype=object)),
#  ('dr.', array(['meets', 'psychiatrist', 'kathryn', 'railly'], dtype=object)),
#  ('kathryn',
#   array(['psychiatrist', 'dr.', 'railly', 'patient'], dtype=object)),
#  ('railly', array(['dr.', 'kathryn', 'patient', 'jeffrey'], dtype=object)),
#  ('patient', array(['kathryn', 'railly', 'jeffrey', 'goines'], dtype=object)),
#  ('jeffrey', array(['railly', 'patient', 'goines', 'son'], dtype=object)),
#  ('goines', array(['patient', 'jeffrey', 'son', 'famous'], dtype=object)),
#  ('son', array(['jeffrey', 'goines', 'famous', 'virus'], dtype=object)),
#  ('famous', array(['goines', 'son', 'virus', 'expert'], dtype=object)),
#  ('virus', array(['son', 'famous', 'expert', 'may'], dtype=object)),
#  ('expert', array(['famous', 'virus', 'may', 'hold'], dtype=object)),
#  ('may', array(['virus', 'expert', 'hold', 'key'], dtype=object)),
#  ('hold', array(['expert', 'may', 'key', 'mysterious'], dtype=object)),
#  ('key', array(['may', 'hold', 'mysterious', 'rogue'], dtype=object)),
#  ('mysterious', array(['hold', 'key', 'rogue', 'group'], dtype=object)),
#  ('rogue', array(['key', 'mysterious', 'group', 'army'], dtype=object)),
#  ('group', array(['mysterious', 'rogue', 'army', '12'], dtype=object)),
#  ('army', array(['rogue', 'group', '12', 'monkeys'], dtype=object)),
#  ('12', array(['group', 'army', 'monkeys', 'thought'], dtype=object)),
#  ('monkeys', array(['army', '12', 'thought', 'responsible'], dtype=object)),
#  ('thought',
#   array(['12', 'monkeys', 'responsible', 'unleashing'], dtype=object)),
#  ('responsible',
#   array(['monkeys', 'thought', 'unleashing', 'killer'], dtype=object)),
#  ('unleashing',
#   array(['thought', 'responsible', 'killer', 'disease'], dtype=object)),
#  ('killer', array(['responsible', 'unleashing', 'disease'], dtype=object)),
#  ('disease', array(['unleashing', 'killer'], dtype=object)),
#  ('babe', array(['little', 'pig'], dtype=object)),
#  ('little', array(['babe', 'pig', "n't"], dtype=object)),
#  ('pig', array(['babe', 'little', "n't", 'quite'], dtype=object)),
#  ("n't", array(['little', 'pig', 'quite', 'know'], dtype=object)),
#  ('quite', array(['pig', "n't", 'know', 'place'], dtype=object)),
#  ('know', array(["n't", 'quite', 'place', 'world'], dtype=object)),
#  ('place', array(['quite', 'know', 'world', 'with'], dtype=object)),
#  ('world', array(['know', 'place', 'with', 'bunch'], dtype=object)),
#  ('with', array(['place', 'world', 'bunch', 'odd'], dtype=object)),
#  ('bunch', array(['world', 'with', 'odd', 'friends'], dtype=object)),
#  ('odd', array(['with', 'bunch', 'friends', 'like'], dtype=object)),
#  ('friends', array(['bunch', 'odd', 'like', 'ferdinand'], dtype=object)),
#  ('like', array(['odd', 'friends', 'ferdinand', 'duck'], dtype=object)),
#  ('ferdinand', array(['friends', 'like', 'duck', 'thinks'], dtype=object)),
#  ('duck', array(['like', 'ferdinand', 'thinks', 'rooster'], dtype=object)),
#  ('thinks', array(['ferdinand', 'duck', 'rooster', 'fly'], dtype=object)),
#  ('rooster', array(['duck', 'thinks', 'fly', 'dog'], dtype=object)),
#  ('fly', array(['thinks', 'rooster', 'dog', 'calls'], dtype=object)),
#  ('dog', array(['rooster', 'fly', 'calls', 'mom'], dtype=object)),
#  ('calls', array(['fly', 'dog', 'mom', 'babe'], dtype=object)),
#  ('mom', array(['dog', 'calls', 'babe', 'realizes'], dtype=object)),
#  ('babe', array(['calls', 'mom', 'realizes', 'makings'], dtype=object)),
#  ('realizes', array(['mom', 'babe', 'makings', 'become'], dtype=object)),
#  ('makings', array(['babe', 'realizes', 'become', 'greatest'], dtype=object)),
#  ('become', array(['realizes', 'makings', 'greatest', 'sheep'], dtype=object)),
#  ('greatest', array(['makings', 'become', 'sheep', 'pig'], dtype=object)),
#  ('sheep', array(['become', 'greatest', 'pig', 'time'], dtype=object)),
#  ('pig', array(['greatest', 'sheep', 'time', 'farmer'], dtype=object)),
#  ('time', array(['sheep', 'pig', 'farmer', 'hogget'], dtype=object)),
#  ('farmer', array(['pig', 'time', 'hogget', 'knows'], dtype=object)),
#  ('hogget', array(['time', 'farmer', 'knows', 'with'], dtype=object)),
#  ('knows', array(['farmer', 'hogget', 'with', 'help'], dtype=object)),
#  ('with', array(['hogget', 'knows', 'help', 'sheep'], dtype=object)),
#  ('help', array(['knows', 'with', 'sheep', 'dogs'], dtype=object)),
#  ('sheep', array(['with', 'help', 'dogs', 'babe'], dtype=object)),
#  ('dogs', array(['help', 'sheep', 'babe', 'learns'], dtype=object)),
#  ('babe', array(['sheep', 'dogs', 'learns', 'pig'], dtype=object)),
#  ('learns', array(['dogs', 'babe', 'pig', 'anything'], dtype=object)),
#  ('pig', array(['babe', 'learns', 'anything', 'wants'], dtype=object)),
#  ('anything', array(['learns', 'pig', 'wants'], dtype=object)),
#  ('wants', array(['pig', 'anything'], dtype=object)),
#  ('a', array(['justice', 'drama'], dtype=object)),
#  ('justice', array(['a', 'drama', 'based'], dtype=object)),
#  ('drama', array(['a', 'justice', 'based', 'true'], dtype=object)),
#  ('based', array(['justice', 'drama', 'true', 'story'], dtype=object)),
#  ('true', array(['drama', 'based', 'story', 'man'], dtype=object)),
#  ('story', array(['based', 'true', 'man', 'death'], dtype=object)),
#  ('man', array(['true', 'story', 'death', 'row'], dtype=object)),
#  ('death', array(['story', 'man', 'row', 'last'], dtype=object)),
#  ('row', array(['man', 'death', 'last', 'days'], dtype=object)),
#  ('last', array(['death', 'row', 'days', 'forms'], dtype=object)),
#  ('days', array(['row', 'last', 'forms', 'strong'], dtype=object)),
#  ('forms', array(['last', 'days', 'strong', 'relationship'], dtype=object)),
#  ('strong', array(['days', 'forms', 'relationship', 'nun'], dtype=object)),
#  ('relationship', array(['forms', 'strong', 'nun', 'teaches'], dtype=object)),
#  ('nun',
#   array(['strong', 'relationship', 'teaches', 'forgiveness'], dtype=object)),
#  ('teaches',
#   array(['relationship', 'nun', 'forgiveness', 'gives'], dtype=object)),
#  ('forgiveness',
#   array(['nun', 'teaches', 'gives', 'spirituality'], dtype=object)),
#  ('gives',
#   array(['teaches', 'forgiveness', 'spirituality', 'accompanies'],
#         dtype=object)),
#  ('spirituality',
#   array(['forgiveness', 'gives', 'accompanies', 'execution'], dtype=object)),
#  ('accompanies',
#   array(['gives', 'spirituality', 'execution', 'susan'], dtype=object)),
#  ('execution',
#   array(['spirituality', 'accompanies', 'susan', 'sarandon'], dtype=object)),
#  ('susan',
#   array(['accompanies', 'execution', 'sarandon', 'oscar'], dtype=object)),
#  ('sarandon', array(['execution', 'susan', 'oscar', 'best'], dtype=object)),
#  ('oscar', array(['susan', 'sarandon', 'best', 'female'], dtype=object)),
#  ('best', array(['sarandon', 'oscar', 'female', 'actress'], dtype=object)),
#  ('female', array(['oscar', 'best', 'actress', 'convincing'], dtype=object)),
#  ('actress',
#   array(['best', 'female', 'convincing', 'portrayal'], dtype=object)),
#  ('convincing',
#   array(['female', 'actress', 'portrayal', 'sister'], dtype=object)),
#  ('portrayal',
#   array(['actress', 'convincing', 'sister', 'helen'], dtype=object)),
#  ('sister',
#   array(['convincing', 'portrayal', 'helen', 'prejean'], dtype=object)),
#  ('helen', array(['portrayal', 'sister', 'prejean'], dtype=object)),
#  ('prejean', array(['sister', 'helen'], dtype=object)),
#  ('susan', array(['wants', 'work'], dtype=object)),
#  ('wants', array(['susan', 'work', 'television'], dtype=object)),
#  ('work', array(['susan', 'wants', 'television', 'therefore'], dtype=object)),
#  ('television',
#   array(['wants', 'work', 'therefore', 'anything'], dtype=object)),
#  ('therefore',
#   array(['work', 'television', 'anything', 'takes'], dtype=object)),
#  ('anything',
#   array(['television', 'therefore', 'takes', 'even'], dtype=object)),
#  ('takes', array(['therefore', 'anything', 'even', 'means'], dtype=object)),
#  ('even', array(['anything', 'takes', 'means', 'killing'], dtype=object)),
#  ('means', array(['takes', 'even', 'killing', 'husband'], dtype=object)),
#  ('killing', array(['even', 'means', 'husband', 'a'], dtype=object)),
#  ('husband', array(['means', 'killing', 'a', 'dark'], dtype=object)),
#  ('a', array(['killing', 'husband', 'dark', 'comedy'], dtype=object)),
#  ('dark', array(['husband', 'a', 'comedy', 'independent'], dtype=object)),
#  ('comedy', array(['a', 'dark', 'independent', 'director'], dtype=object)),
#  ('independent', array(['dark', 'comedy', 'director', 'gus'], dtype=object)),
#  ('director', array(['comedy', 'independent', 'gus', 'van'], dtype=object)),
#  ('gus', array(['independent', 'director', 'van', 'sant'], dtype=object)),
#  ('van', array(['director', 'gus', 'sant', 'brilliant'], dtype=object)),
#  ('sant', array(['gus', 'van', 'brilliant', 'nicole'], dtype=object)),
#  ('brilliant', array(['van', 'sant', 'nicole', 'kidman'], dtype=object)),
#  ('nicole', array(['sant', 'brilliant', 'kidman', 'leading'], dtype=object)),
#  ('kidman', array(['brilliant', 'nicole', 'leading', 'role'], dtype=object)),
#  ('leading', array(['nicole', 'kidman', 'role'], dtype=object)),
#  ('role', array(['kidman', 'leading'], dtype=object)),
#  ('two', array(['homicide', 'detectives'], dtype=object)),
#  ('homicide', array(['two', 'detectives', 'desperate'], dtype=object)),
#  ('detectives', array(['two', 'homicide', 'desperate', 'hunt'], dtype=object)),
#  ('desperate',
#   array(['homicide', 'detectives', 'hunt', 'serial'], dtype=object)),
#  ('hunt',
#   array(['detectives', 'desperate', 'serial', 'killer'], dtype=object)),
#  ('serial', array(['desperate', 'hunt', 'killer', 'whose'], dtype=object)),
#  ('killer', array(['hunt', 'serial', 'whose', 'crimes'], dtype=object)),
#  ('whose', array(['serial', 'killer', 'crimes', 'based'], dtype=object)),
#  ('crimes', array(['killer', 'whose', 'based', '``'], dtype=object)),
#  ('based', array(['whose', 'crimes', '``', 'seven'], dtype=object)),
#  ('``', array(['crimes', 'based', 'seven', 'deadly'], dtype=object)),
#  ('seven', array(['based', '``', 'deadly', 'sins'], dtype=object)),
#  ('deadly', array(['``', 'seven', 'sins', 'dark'], dtype=object)),
#  ('sins', array(['seven', 'deadly', 'dark', 'haunting'], dtype=object)),
#  ('dark', array(['deadly', 'sins', 'haunting', 'film'], dtype=object)),
#  ('haunting', array(['sins', 'dark', 'film', 'takes'], dtype=object)),
#  ('film', array(['dark', 'haunting', 'takes', 'viewers'], dtype=object)),
#  ('takes', array(['haunting', 'film', 'viewers', 'tortured'], dtype=object)),
#  ('viewers', array(['film', 'takes', 'tortured', 'remains'], dtype=object)),
#  ('tortured', array(['takes', 'viewers', 'remains', 'one'], dtype=object)),
#  ('remains', array(['viewers', 'tortured', 'one', 'victim'], dtype=object)),
#  ('one', array(['tortured', 'remains', 'victim', 'next'], dtype=object)),
#  ('victim', array(['remains', 'one', 'next', 'the'], dtype=object)),
#  ('next', array(['one', 'victim', 'the', 'seasoned'], dtype=object)),
#  ('the', array(['victim', 'next', 'seasoned', 'det'], dtype=object)),
#  ('seasoned', array(['next', 'the', 'det', 'sommerset'], dtype=object)),
#  ('det', array(['the', 'seasoned', 'sommerset', 'researches'], dtype=object)),
#  ('sommerset', array(['seasoned', 'det', 'researches', 'sin'], dtype=object)),
#  ('researches', array(['det', 'sommerset', 'sin', 'effort'], dtype=object)),
#  ('sin', array(['sommerset', 'researches', 'effort', 'get'], dtype=object)),
#  ('effort', array(['researches', 'sin', 'get', 'inside'], dtype=object)),
#  ('get', array(['sin', 'effort', 'inside', 'killer'], dtype=object)),
#  ('inside', array(['effort', 'get', 'killer', "'s"], dtype=object)),
#  ('killer', array(['get', 'inside', "'s", 'mind'], dtype=object)),
#  ("'s", array(['inside', 'killer', 'mind', 'novice'], dtype=object)),
#  ('mind', array(['killer', "'s", 'novice', 'partner'], dtype=object)),
#  ('novice', array(["'s", 'mind', 'partner', 'mills'], dtype=object)),
#  ('partner', array(['mind', 'novice', 'mills', 'scoffs'], dtype=object)),
#  ('mills', array(['novice', 'partner', 'scoffs', 'efforts'], dtype=object)),
#  ('scoffs', array(['partner', 'mills', 'efforts', 'unravel'], dtype=object)),
#  ('efforts', array(['mills', 'scoffs', 'unravel', 'case'], dtype=object)),
#  ('unravel', array(['scoffs', 'efforts', 'case'], dtype=object)),
#  ('case', array(['efforts', 'unravel'], dtype=object)),
#  ('history', array(['comes', 'gloriously'], dtype=object)),
#  ('comes', array(['history', 'gloriously', 'life'], dtype=object)),
#  ('gloriously', array(['history', 'comes', 'life', 'disney'], dtype=object)),
#  ('life', array(['comes', 'gloriously', 'disney', "'s"], dtype=object)),
#  ('disney', array(['gloriously', 'life', "'s", 'epic'], dtype=object)),
#  ("'s", array(['life', 'disney', 'epic', 'animated'], dtype=object)),
#  ('epic', array(['disney', "'s", 'animated', 'tale'], dtype=object)),
#  ('animated', array(["'s", 'epic', 'tale', 'love'], dtype=object)),
#  ('tale', array(['epic', 'animated', 'love', 'adventure'], dtype=object)),
#  ('love', array(['animated', 'tale', 'adventure', 'new'], dtype=object)),
#  ('adventure', array(['tale', 'love', 'new', 'world'], dtype=object)),
#  ('new', array(['love', 'adventure', 'world', 'pocahontas'], dtype=object)),
#  ('world', array(['adventure', 'new', 'pocahontas', 'native'], dtype=object)),
#  ('pocahontas', array(['new', 'world', 'native', 'american'], dtype=object)),
#  ('native', array(['world', 'pocahontas', 'american', 'woman'], dtype=object)),
#  ('american', array(['pocahontas', 'native', 'woman', 'whose'], dtype=object)),
#  ('woman', array(['native', 'american', 'whose', 'father'], dtype=object)),
#  ('whose', array(['american', 'woman', 'father', 'arranged'], dtype=object)),
#  ('father', array(['woman', 'whose', 'arranged', 'marry'], dtype=object)),
#  ('arranged', array(['whose', 'father', 'marry', 'village'], dtype=object)),
#  ('marry', array(['father', 'arranged', 'village', "'s"], dtype=object)),
#  ('village', array(['arranged', 'marry', "'s", 'best'], dtype=object)),
#  ("'s", array(['marry', 'village', 'best', 'warrior'], dtype=object)),
#  ('best', array(['village', "'s", 'warrior', 'but'], dtype=object)),
#  ('warrior', array(["'s", 'best', 'but', 'vision'], dtype=object)),
#  ('but', array(['best', 'warrior', 'vision', 'tells'], dtype=object)),
#  ('vision', array(['warrior', 'but', 'tells', 'change'], dtype=object)),
#  ('tells', array(['but', 'vision', 'change', 'coming'], dtype=object)),
# ...
#  ('craig', array(['smokey', 'two'], dtype=object)),
#  ('smokey', array(['craig', 'two', 'guys'], dtype=object)),
#  ('two', array(['craig', 'smokey', 'guys', 'los'], dtype=object)),
#  ('guys', array(['smokey', 'two', 'los', 'angeles'], dtype=object)),
#  ('los', array(['two', 'guys', 'angeles', 'hanging'], dtype=object)),
#  ('angeles', array(['guys', 'los', 'hanging', 'porch'], dtype=object)),
#  ('hanging', array(['los', 'angeles', 'porch', 'friday'], dtype=object)),
#  ('porch', array(['angeles', 'hanging', 'friday', 'afternoon'], dtype=object)),
#  ('friday', array(['hanging', 'porch', 'afternoon', 'smoking'], dtype=object)),
#  ('afternoon',
#   array(['porch', 'friday', 'smoking', 'drinking'], dtype=object)),
#  ('smoking',
#   array(['friday', 'afternoon', 'drinking', 'looking'], dtype=object)),
#  ('drinking',
#   array(['afternoon', 'smoking', 'looking', 'something'], dtype=object)),
#  ('looking', array(['smoking', 'drinking', 'something'], dtype=object)),
#  ('something', array(['drinking', 'looking'], dtype=object)),
#  ('seth', array(['gecko', 'younger'], dtype=object)),
#  ('gecko', array(['seth', 'younger', 'brother'], dtype=object)),
#  ('younger', array(['seth', 'gecko', 'brother', 'richard'], dtype=object)),
#  ('brother', array(['gecko', 'younger', 'richard', 'run'], dtype=object)),
#  ('richard', array(['younger', 'brother', 'run', 'bloody'], dtype=object)),
#  ('run', array(['brother', 'richard', 'bloody', 'bank'], dtype=object)),
#  ('bloody', array(['richard', 'run', 'bank', 'robbery'], dtype=object)),
#  ('bank', array(['run', 'bloody', 'robbery', 'texas'], dtype=object)),
#  ('robbery', array(['bloody', 'bank', 'texas', 'they'], dtype=object)),
#  ('texas', array(['bank', 'robbery', 'they', 'escape'], dtype=object)),
#  ('they', array(['robbery', 'texas', 'escape', 'across'], dtype=object)),
#  ('escape', array(['texas', 'they', 'across', 'border'], dtype=object)),
#  ('across', array(['they', 'escape', 'border', 'mexico'], dtype=object)),
#  ('border', array(['escape', 'across', 'mexico', 'home-free'], dtype=object)),
#  ('mexico', array(['across', 'border', 'home-free', 'next'], dtype=object)),
#  ('home-free', array(['border', 'mexico', 'next', 'morning'], dtype=object)),
#  ('next', array(['mexico', 'home-free', 'morning', 'pay'], dtype=object)),
#  ('morning', array(['home-free', 'next', 'pay', 'local'], dtype=object)),
#  ('pay', array(['next', 'morning', 'local', 'kingpin'], dtype=object)),
#  ('local', array(['morning', 'pay', 'kingpin', 'they'], dtype=object)),
#  ('kingpin', array(['pay', 'local', 'they', 'survive'], dtype=object)),
#  ('they', array(['local', 'kingpin', 'survive', "'from"], dtype=object)),
#  ('survive', array(['kingpin', 'they', "'from", 'dusk'], dtype=object)),
#  ("'from", array(['they', 'survive', 'dusk', 'till'], dtype=object)),
#  ('dusk', array(['survive', "'from", 'till', 'dawn'], dtype=object)),
#  ('till', array(["'from", 'dusk', 'dawn', 'rendezvous'], dtype=object)),
#  ('dawn', array(['dusk', 'till', 'rendezvous', 'point'], dtype=object)),
#  ('rendezvous', array(['till', 'dawn', 'point', 'turns'], dtype=object)),
#  ('point', array(['dawn', 'rendezvous', 'turns', 'hell'], dtype=object)),
#  ('turns', array(['rendezvous', 'point', 'hell', 'strip'], dtype=object)),
#  ('hell', array(['point', 'turns', 'strip', 'joint'], dtype=object)),
#  ('strip', array(['turns', 'hell', 'joint'], dtype=object)),
#  ('joint', array(['hell', 'strip'], dtype=object)),
#  ('sirius', array(['6b', 'year'], dtype=object)),
#  ('6b', array(['sirius', 'year', '2078'], dtype=object)),
#  ('year', array(['sirius', '6b', '2078', 'on'], dtype=object)),
#  ('2078', array(['6b', 'year', 'on', 'distant'], dtype=object)),
#  ('on', array(['year', '2078', 'distant', 'mining'], dtype=object)),
#  ('distant', array(['2078', 'on', 'mining', 'planet'], dtype=object)),
#  ('mining', array(['on', 'distant', 'planet', 'ravaged'], dtype=object)),
#  ('planet', array(['distant', 'mining', 'ravaged', 'decade'], dtype=object)),
#  ('ravaged', array(['mining', 'planet', 'decade', 'war'], dtype=object)),
#  ('decade', array(['planet', 'ravaged', 'war', 'scientists'], dtype=object)),
#  ('war', array(['ravaged', 'decade', 'scientists', 'created'], dtype=object)),
#  ('scientists', array(['decade', 'war', 'created', 'perfect'], dtype=object)),
#  ('created', array(['war', 'scientists', 'perfect', 'weapon'], dtype=object)),
#  ('perfect',
#   array(['scientists', 'created', 'weapon', 'blade-wielding'], dtype=object)),
#  ('weapon',
#   array(['created', 'perfect', 'blade-wielding', 'self-replicating'],
#         dtype=object)),
#  ('blade-wielding',
#   array(['perfect', 'weapon', 'self-replicating', 'race'], dtype=object)),
#  ('self-replicating',
#   array(['weapon', 'blade-wielding', 'race', 'killing'], dtype=object)),
#  ('race',
#   array(['blade-wielding', 'self-replicating', 'killing', 'devices'],
#         dtype=object)),
#  ('killing',
#   array(['self-replicating', 'race', 'devices', 'known'], dtype=object)),
#  ('devices', array(['race', 'killing', 'known', 'screamers'], dtype=object)),
#  ('known',
#   array(['killing', 'devices', 'screamers', 'designed'], dtype=object)),
#  ('screamers', array(['devices', 'known', 'designed', 'one'], dtype=object)),
#  ('designed', array(['known', 'screamers', 'one', 'purpose'], dtype=object)),
#  ('one', array(['screamers', 'designed', 'purpose', '--'], dtype=object)),
#  ('purpose', array(['designed', 'one', '--', 'hunt'], dtype=object)),
#  ('--', array(['one', 'purpose', 'hunt', 'destroy'], dtype=object)),
#  ('hunt', array(['purpose', '--', 'destroy', 'enemy'], dtype=object)),
#  ('destroy', array(['--', 'hunt', 'enemy', 'life'], dtype=object)),
#  ('enemy', array(['hunt', 'destroy', 'life', 'forms'], dtype=object)),
#  ('life', array(['destroy', 'enemy', 'forms'], dtype=object)),
#  ('forms', array(['enemy', 'life'], dtype=object)),
#  ('gene', array(['watson', 'public'], dtype=object)),
#  ('watson', array(['gene', 'public', 'accountant'], dtype=object)),
#  ('public', array(['gene', 'watson', 'accountant', 'arrives'], dtype=object)),
#  ('accountant', array(['watson', 'public', 'arrives', 'train'], dtype=object)),
#  ('arrives', array(['public', 'accountant', 'train', 'union'], dtype=object)),
#  ('train', array(['accountant', 'arrives', 'union', 'station'], dtype=object)),
#  ('union', array(['arrives', 'train', 'station', 'los'], dtype=object)),
#  ('station', array(['train', 'union', 'los', 'angeles'], dtype=object)),
#  ('los', array(['union', 'station', 'angeles', 'accompanied'], dtype=object)),
#  ('angeles',
#   array(['station', 'los', 'accompanied', '6-year-old'], dtype=object)),
#  ('accompanied',
#   array(['los', 'angeles', '6-year-old', 'daughter'], dtype=object)),
#  ('6-year-old',
#   array(['angeles', 'accompanied', 'daughter', 'lynn'], dtype=object)),
#  ('daughter',
#   array(['accompanied', '6-year-old', 'lynn', 'because'], dtype=object)),
#  ('lynn',
#   array(['6-year-old', 'daughter', 'because', 'ordinary'], dtype=object)),
#  ('because', array(['daughter', 'lynn', 'ordinary', 'looks'], dtype=object)),
#  ('ordinary', array(['lynn', 'because', 'looks', 'approached'], dtype=object)),
#  ('looks', array(['because', 'ordinary', 'approached', 'pair'], dtype=object)),
#  ('approached',
#   array(['ordinary', 'looks', 'pair', 'sinister'], dtype=object)),
#  ('pair', array(['looks', 'approached', 'sinister', 'people'], dtype=object)),
#  ('sinister', array(['approached', 'pair', 'people', 'named'], dtype=object)),
#  ('people', array(['pair', 'sinister', 'named', 'smith'], dtype=object)),
#  ('named', array(['sinister', 'people', 'smith', 'jones'], dtype=object)),
#  ('smith', array(['people', 'named', 'jones'], dtype=object)),
#  ('jones', array(['named', 'smith'], dtype=object)),
#  ('failed', array(['hockey', 'player-turned-golf'], dtype=object)),
#  ('hockey', array(['failed', 'player-turned-golf', 'whiz'], dtype=object)),
#  ('player-turned-golf',
#   array(['failed', 'hockey', 'whiz', 'happy'], dtype=object)),
#  ('whiz',
#   array(['hockey', 'player-turned-golf', 'happy', 'gilmore'], dtype=object)),
#  ('happy',
#   array(['player-turned-golf', 'whiz', 'gilmore', '--'], dtype=object)),
#  ('gilmore', array(['whiz', 'happy', '--', 'whose'], dtype=object)),
#  ('--', array(['happy', 'gilmore', 'whose', 'unconventional'], dtype=object)),
#  ('whose',
#   array(['gilmore', '--', 'unconventional', 'approach'], dtype=object)),
#  ('unconventional',
#   array(['--', 'whose', 'approach', 'antics'], dtype=object)),
#  ('approach',
#   array(['whose', 'unconventional', 'antics', 'grass'], dtype=object)),
#  ('antics',
#   array(['unconventional', 'approach', 'grass', 'courts'], dtype=object)),
#  ('grass', array(['approach', 'antics', 'courts', 'ire'], dtype=object)),
#  ('courts', array(['antics', 'grass', 'ire', 'rival'], dtype=object)),
#  ('ire', array(['grass', 'courts', 'rival', 'shooter'], dtype=object)),
#  ('rival', array(['courts', 'ire', 'shooter', 'mcgavin'], dtype=object)),
#  ('shooter', array(['ire', 'rival', 'mcgavin', '--'], dtype=object)),
#  ('mcgavin', array(['rival', 'shooter', '--', 'determined'], dtype=object)),
#  ('--', array(['shooter', 'mcgavin', 'determined', 'win'], dtype=object)),
#  ('determined', array(['mcgavin', '--', 'win', 'pga'], dtype=object)),
#  ('win', array(['--', 'determined', 'pga', 'tournament'], dtype=object)),
#  ('pga', array(['determined', 'win', 'tournament', 'save'], dtype=object)),
#  ('tournament', array(['win', 'pga', 'save', 'granny'], dtype=object)),
#  ('save', array(['pga', 'tournament', 'granny', "'s"], dtype=object)),
#  ('granny', array(['tournament', 'save', "'s", 'house'], dtype=object)),
#  ("'s", array(['save', 'granny', 'house', 'prize'], dtype=object)),
#  ('house', array(['granny', "'s", 'prize', 'money'], dtype=object)),
#  ('prize', array(["'s", 'house', 'money', 'meanwhile'], dtype=object)),
#  ('money', array(['house', 'prize', 'meanwhile', 'attractive'], dtype=object)),
#  ('meanwhile', array(['prize', 'money', 'attractive', 'tour'], dtype=object)),
#  ('attractive',
#   array(['money', 'meanwhile', 'tour', 'publicist'], dtype=object)),
#  ('tour',
#   array(['meanwhile', 'attractive', 'publicist', 'tries'], dtype=object)),
#  ('publicist', array(['attractive', 'tour', 'tries', 'soften'], dtype=object)),
#  ('tries', array(['tour', 'publicist', 'soften', 'happy'], dtype=object)),
#  ('soften', array(['publicist', 'tries', 'happy', "'s"], dtype=object)),
#  ('happy', array(['tries', 'soften', "'s", 'image'], dtype=object)),
#  ("'s", array(['soften', 'happy', 'image'], dtype=object)),
#  ('image', array(['happy', "'s"], dtype=object)),
#  ('photographer', array(['robert', 'kincaid'], dtype=object)),
#  ('robert', array(['photographer', 'kincaid', 'wanders'], dtype=object)),
#  ('kincaid',
#   array(['photographer', 'robert', 'wanders', 'life'], dtype=object)),
#  ('wanders', array(['robert', 'kincaid', 'life', 'housewife'], dtype=object)),
#  ('life',
#   array(['kincaid', 'wanders', 'housewife', 'francesca'], dtype=object)),
#  ('housewife',
#   array(['wanders', 'life', 'francesca', 'johnson'], dtype=object)),
#  ('francesca', array(['life', 'housewife', 'johnson', 'four'], dtype=object)),
#  ('johnson', array(['housewife', 'francesca', 'four', 'days'], dtype=object)),
#  ('four', array(['francesca', 'johnson', 'days', '1960s'], dtype=object)),
#  ('days', array(['johnson', 'four', '1960s'], dtype=object)),
#  ('1960s', array(['four', 'days'], dtype=object)),
#  ('enraged', array(['slaughter', 'murron'], dtype=object)),
#  ('slaughter', array(['enraged', 'murron', 'new'], dtype=object)),
#  ('murron', array(['enraged', 'slaughter', 'new', 'bride'], dtype=object)),
#  ('new', array(['slaughter', 'murron', 'bride', 'childhood'], dtype=object)),
#  ('bride', array(['murron', 'new', 'childhood', 'love'], dtype=object)),
#  ('childhood', array(['new', 'bride', 'love', 'scottish'], dtype=object)),
#  ('love', array(['bride', 'childhood', 'scottish', 'warrior'], dtype=object)),
#  ('scottish',
#   array(['childhood', 'love', 'warrior', 'william'], dtype=object)),
#  ('warrior', array(['love', 'scottish', 'william', 'wallace'], dtype=object)),
#  ('william', array(['scottish', 'warrior', 'wallace', 'slays'], dtype=object)),
#  ('wallace', array(['warrior', 'william', 'slays', 'platoon'], dtype=object)),
#  ('slays', array(['william', 'wallace', 'platoon', 'local'], dtype=object)),
#  ('platoon', array(['wallace', 'slays', 'local', 'english'], dtype=object)),
#  ('local', array(['slays', 'platoon', 'english', 'lord'], dtype=object)),
#  ('english', array(['platoon', 'local', 'lord', "'s"], dtype=object)),
#  ('lord', array(['local', 'english', "'s", 'soldiers'], dtype=object)),
#  ("'s", array(['english', 'lord', 'soldiers', 'this'], dtype=object)),
#  ('soldiers', array(['lord', "'s", 'this', 'leads'], dtype=object)),
#  ('this', array(["'s", 'soldiers', 'leads', 'village'], dtype=object)),
#  ('leads', array(['soldiers', 'this', 'village', 'revolt'], dtype=object)),
#  ('village', array(['this', 'leads', 'revolt', 'eventually'], dtype=object)),
#  ('revolt', array(['leads', 'village', 'eventually', 'entire'], dtype=object)),
#  ('eventually',
#   array(['village', 'revolt', 'entire', 'country'], dtype=object)),
#  ('entire', array(['revolt', 'eventually', 'country', 'rise'], dtype=object)),
#  ('country', array(['eventually', 'entire', 'rise', 'english'], dtype=object)),
#  ('rise', array(['entire', 'country', 'english', 'rule'], dtype=object)),
#  ('english', array(['country', 'rise', 'rule'], dtype=object)),
#  ('rule', array(['rise', 'english'], dtype=object)),
#  ('a', array(['mentally', 'unstable'], dtype=object)),
#  ('mentally', array(['a', 'unstable', 'vietnam'], dtype=object)),
#  ('unstable', array(['a', 'mentally', 'vietnam', 'war'], dtype=object)),
#  ('vietnam', array(['mentally', 'unstable', 'war', 'veteran'], dtype=object)),
#  ('war', array(['unstable', 'vietnam', 'veteran', 'works'], dtype=object)),
#  ('veteran', array(['vietnam', 'war', 'works', 'night-time'], dtype=object)),
#  ('works', array(['war', 'veteran', 'night-time', 'taxi'], dtype=object)),
#  ('night-time', array(['veteran', 'works', 'taxi', 'driver'], dtype=object)),
#  ('taxi', array(['works', 'night-time', 'driver', 'new'], dtype=object)),
#  ('driver', array(['night-time', 'taxi', 'new', 'york'], dtype=object)),
#  ('new', array(['taxi', 'driver', 'york', 'city'], dtype=object)),
#  ('york', array(['driver', 'new', 'city', 'perceived'], dtype=object)),
#  ('city', array(['new', 'york', 'perceived', 'decadence'], dtype=object)),
#  ('perceived', array(['york', 'city', 'decadence', 'sleaze'], dtype=object)),
#  ('decadence', array(['city', 'perceived', 'sleaze', 'feeds'], dtype=object)),
#  ('sleaze', array(['perceived', 'decadence', 'feeds', 'urge'], dtype=object)),
#  ('feeds', array(['decadence', 'sleaze', 'urge', 'violent'], dtype=object)),
#  ('urge', array(['sleaze', 'feeds', 'violent', 'action'], dtype=object)),
#  ('violent', array(['feeds', 'urge', 'action', 'attempting'], dtype=object)),
#  ('action', array(['urge', 'violent', 'attempting', 'save'], dtype=object)),
#  ('attempting',
#   array(['violent', 'action', 'save', 'preadolescent'], dtype=object)),
#  ('save',
#   array(['action', 'attempting', 'preadolescent', 'prostitute'],
#         dtype=object)),
#  ('preadolescent',
#   array(['attempting', 'save', 'prostitute', 'process'], dtype=object)),
#  ('prostitute', array(['save', 'preadolescent', 'process'], dtype=object)),
#  ('process', array(['preadolescent', 'prostitute'], dtype=object)),
#  ('keong', array(['comes', 'hong'], dtype=object)),
#  ('comes', array(['keong', 'hong', 'kong'], dtype=object)),
#  ('hong', array(['keong', 'comes', 'kong', 'visit'], dtype=object)),
#  ('kong', array(['comes', 'hong', 'visit', 'new'], dtype=object)),
#  ('visit', array(['hong', 'kong', 'new', 'york'], dtype=object)),
#  ('new', array(['kong', 'visit', 'york', 'uncle'], dtype=object)),
#  ('york', array(['visit', 'new', 'uncle', "'s"], dtype=object)),
#  ('uncle', array(['new', 'york', "'s", 'wedding'], dtype=object)),
#  ("'s", array(['york', 'uncle', 'wedding', 'his'], dtype=object)),
#  ('wedding', array(['uncle', "'s", 'his', 'uncle'], dtype=object)),
#  ('his', array(["'s", 'wedding', 'uncle', 'runs'], dtype=object)),
#  ('uncle', array(['wedding', 'his', 'runs', 'market'], dtype=object)),
#  ...]

# %% [markdown]
# <div style="background-color: #dd6108; color: #ffffff; padding: 10px;">
# <h3>3. Building the neural network
# </div>

# %% [markdown]
# Our next step is building the Neural Network. Both architectures are different but still share some common patterns. Let's discuss it with more detail.
#
# Abbreviations used:
# - **$B$**: Batch size
# - **$V$**: Vocabulary size
# - **$S$**: Embeddings size
# - **$W_i$**: Weight matrices

# %% [markdown]
# #### 3.1 CBoW
#
# The CBoW model follows a shallow, two-layer neural network design:
#
# 1. **Input Layer**
#
#    The input for every training data point consists of a sparse vector of size $V$ for each context token surrounding the target token. Those vectors are obtained by one hot encoding the tokens using the vocabulary, and together they are represented by a matrix of size of at most $2C \times V$. As they basically work as a lookup table, we can add them together to get a sparse vector of size $V$ with so many ones as context tokens, if not token is repeated.
#
# 2. **Projection Layer (Hidden Layer)**
#
#     The hidden layer consists of a single dense layer with a weight matrix $W_1$ of shape $V \times N$.
#
#     For each data point, the input vector is projected into this dense layer, and their embeddings are **averaged** to form a single vector representation.
#
# 3. **Output Layer**
#
#     The output layer is a softmax classifier that predicts the target token.
#     It contains a second weight matrix $W_2$ of shape $N \times V$.
#     The output is a probability distribution over the vocabulary, indicating the likelihood of each word being the correct target.

# %% [markdown]
# Wait, why do we average instead of just adding?
#
# - **Preventing Magnitude Issues**: If we sum the word embeddings, the resulting vector's magnitude depends on the number of context words. Larger context windows would lead to larger summed values, making training unstable. Averaging normalizes this effect, ensuring that all context sizes contribute equally.
# - **Consistency Across Different Context Sizes**: If we sum, a sentence with a larger context window would have a significantly different vector scale compared to a sentence with a smaller context window. Averaging ensures that the model learns embeddings that are scale-invariant to the number of context words.
# - **Smoother Optimization & Stable Learning**: Gradient updates become more stable with averaging. If we sum, the magnitude of gradients would vary based on the number of context words, leading to inconsistent learning rates. Averaging keeps gradients on a consistent scale, making training more efficient.

# %% [markdown]
# ##### 3.1.1 Writing the class
#
# Let's start putting everything together. We will start defining a class called <kbd>Word2VecCBOW</kbd> and write its initialization function. We will need to pass some parameters when we instatiate the class:
# - **vocab_size**
# - **embedding_dim**
# - **learning_rate** (with a default value of 0.01)
#
# We will also initialize our weights matrices W1 and W2 with <kbd>np.random.uniform</kbd> with values between -1 and 1.

# %%
# your code here
class Word2VecCBOW:
    def __init__(...):
        self.vocab_size = ...
        self.embedding_dim = ...
        self.learning_rate = ...
        
        # Initialize weight matrices
        self.W1 = ...  # Input to hidden
        self.W2 = ...  # Hidden to output

# %%
## SOLUTION
class Word2VecCBOW:
    def __init__(self, vocab_size, embedding_dim, learning_rate=0.01):
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.learning_rate = learning_rate
        
        # Initialize weight matrices
        self.W1 = np.random.uniform(-1, 1, (vocab_size, embedding_dim))  # Input to hidden
        self.W2 = np.random.uniform(-1, 1, (embedding_dim, vocab_size))  # Hidden to output

# %% [markdown]
# Oh! Only weights? Why there is no Bias vector in CBoW?
#
# There are a few reasons for it:
#
# - **Simplicity**: Adding a bias term doesn’t significantly improve the embeddings, so it's often omitted to keep the model lightweight.
# - **Embedding Interpretation**: The key part of training Word2Vec is learning the weight matrix $W$, which directly maps words to dense vector representations. Bias terms would shift the embeddings, but since embeddings are used in similarity computations (dot product or cosine similarity), shifting them doesn't add much value.
# - **Averaging Mechanism**: Since CBoW averages the input word vectors before passing them to the softmax layer, a bias term wouldn’t have the same impact as in standard neural networks. The model mainly relies on word co-occurrence patterns, and the averaged embeddings already provide a useful contextual signal.

# %% [markdown]
# ##### 3.1.2 The input layer
#
# We prepare now the input vectors.
#
# Since the input (one-hot encoding) vectors effectively act as a lookup table for the weight matrix $W_1$​, selecting only specific rows, we can bypass the explicit creation of one-hot vectors. Instead, we'll directly use their indices to access the corresponding rows in $W_1$​ using NumPy's fancy indexing.

# %%
training_idx = [[token_to_idx[item[0]], [token_to_idx[token] for token in item[1]]] for item in training_data]

# %%
training_idx
# Out:
# [[13503, [8904, 15716]],
#  [8904, [13503, 15716, 446]],
#  [15716, [13503, 8904, 446, 2123]],
#  [446, [8904, 15716, 2123, 15176]],
#  [2123, [15716, 446, 15176, 15689]],
#  [15176, [446, 2123, 15689, 4025]],
#  [15689, [2123, 15176, 4025, 15716]],
#  [4025, [15176, 15689, 15716, 446]],
#  [15716, [15689, 4025, 446, 11405]],
#  [446, [4025, 15716, 11405, 16613]],
#  [11405, [15716, 446, 16613, 10393]],
#  [16613, [446, 11405, 10393, 9275]],
#  [10393, [11405, 16613, 9275, 16250]],
#  [9275, [16613, 10393, 16250, 11369]],
#  [16250, [10393, 9275, 11369, 10530]],
#  [11369, [9275, 16250, 10530, 866]],
#  [10530, [16250, 11369, 866, 11513]],
#  [866, [11369, 10530, 11513, 15716]],
#  [11513, [10530, 866, 15716, 446]],
#  [15716, [866, 11513, 446, 12036]],
#  [446, [11513, 15716, 12036, 8904]],
#  [12036, [15716, 446, 8904, 15302]],
#  [8904, [446, 12036, 15302, 10393]],
#  [15302, [12036, 8904, 10393, 1335]],
#  [10393, [8904, 15302, 1335, 8464]],
#  [1335, [15302, 10393, 8464, 9362]],
#  [8464, [10393, 1335, 9362, 10393]],
#  [9362, [1335, 8464, 10393, 8904]],
#  [10393, [8464, 9362, 8904, 7612]],
#  [8904, [9362, 10393, 7612, 6591]],
#  [7612, [10393, 8904, 6591, 16358]],
#  [6591, [8904, 7612, 16358, 87]],
#  [16358, [7612, 6591, 87, 13236]],
#  [87, [6591, 16358, 13236, 12449]],
#  [13236, [16358, 87, 12449, 16630]],
#  [12449, [87, 13236, 16630]],
#  [16630, [13236, 12449]],
#  [587, [12760, 8673]],
#  [12760, [587, 8673, 14356]],
#  [8673, [587, 12760, 14356, 7001]],
#  [14356, [12760, 8673, 7001, 3534]],
#  [7001, [8673, 14356, 3534, 1336]],
#  [3534, [14356, 7001, 1336, 4849]],
#  [1336, [7001, 3534, 4849, 16998]],
#  [4849, [3534, 1336, 16998, 5732]],
#  [16998, [1336, 4849, 5732, 9395]],
#  [5732, [4849, 16998, 9395, 8990]],
#  [9395, [16998, 5732, 8990, 13164]],
#  [8990, [5732, 9395, 13164, 6327]],
#  [15943, [7595, 7529, 7095, 15153]],
#  [7095, [7529, 15943, 15153, 14168]],
#  [15153, [15943, 7095, 14168, 9174]],
#  [14168, [7095, 15153, 9174, 9115]],
#  [9174, [15153, 14168, 9115, 4258]],
#  [9115, [14168, 9174, 4258]],
#  [4258, [9174, 9115]],
#  [2536, [6482, 16140]],
#  [6482, [2536, 16140, 9513]],
#  [16140, [2536, 6482, 9513, 15387]],
#  [9513, [6482, 16140, 15387, 1669]],
#  [15387, [16140, 9513, 1669, 12608]],
#  [1669, [9513, 15387, 12608, 167]],
#  [12608, [15387, 1669, 167, 446]],
#  [167, [1669, 12608, 446, 16740]],
#  [446, [12608, 167, 16740, 6687]],
#  [16740, [167, 446, 6687, 167]],
#  [6687, [446, 16740, 167, 1373]],
#  [167, [16740, 6687, 1373, 2620]],
#  ...]

# %% [markdown]
# ##### 3.1.3 Forward Pass
#
# In this step the input vectors are multiplied by the embedding matrix $W_1$ and averaged. The averaged vector is then passed through the output weight matrix $W_2$ and a softmax activation is applied to produce a probability distribution over all words in the vocabulary.
#
# Let's write the function that will do that for us.

# %%
# Your code here
def forward(self, context):

        h = ...  # Shape: (1, embedding_dim)
        
        # Compute output scores
        u = ...  # Shape: (1, vocab_size)
        
        # Softmax activation
        y_pred = ...
        
        return h, y_pred

setattr(Word2VecCBOW, 'forward', forward)

# %%
## SOLUTION
def forward(self, context):
        h = np.mean(self.W1[[context]], axis=1)  # Shape: (1, embedding_dim)
        
        # Compute output scores
        u = np.dot(h, self.W2)  # Shape: (1, vocab_size)
        
        # Softmax activation
        y_pred = np.exp(u) / np.sum(np.exp(u))

        return h, y_pred

setattr(Word2VecCBOW, 'forward', forward)

# %% [markdown]
# ##### 3.1.4 Loss and Backpropagation
#
# We want to train the model using Cross-Entropy Loss. So, given our output
#
# $\hat{y}_i = \frac{e^{u_i}}{\sum_j e^{u_j}}$
#
# the Cross-Entropy-Loss is
#
# $L = -\sum\limits_{i \in context} \hat{y}_i$
#
# The gradient with respect to the pre-softmax scores $u$ (logits) is then
#
# $\frac{\partial L}{\partial u} = \hat{y} - y$
#
# That leads to
#
# $\frac{\partial L}{\partial W_2} = h^\intercal (\hat{y} - y)$,
#
# $\frac{\partial L}{\partial h} = (\hat{y} - y) W_2^\intercal$,
#
# and
#
# $\frac{\partial L}{\partial W_1} = \frac{1}{N} (\hat{y} - y) W_2^\intercal$
#
# for those rows corresponding to the tokens in the context, with N the context size.

# %%
# Your code here
def backward(self, context, target, h, y_pred):
        # Compute error (difference between prediction and target one-hot vector)
        error = ...  # Shape: (1, vocab_size)
        
        # Gradients for W2
        dW2 = ...  # Shape: (embedding_dim, vocab_size)
        
        # Gradients for W1
        dW1 = ...)  # Shape: (1, embedding_dim)
                                                       # for every token in context
        
        # Update weights
        self.W1[[context]] -= self.learning_rate * dW1
        self.W2 -= self.learning_rate * dW2

setattr(Word2VecCBOW, 'backward', backward)

# %%
## SOLUTION
def backward(self, context, target, h, y_pred):
        # Compute error (difference between prediction and target one-hot vector)
        error = y_pred - np.eye(vocab_size)[target]  # Shape: (1, vocab_size)

        # Gradients for W2
        dW2 = np.dot(h.T, error)  # Shape: (embedding_dim, vocab_size)

        # Gradients for W1
        dW1 = np.dot(error, self.W2.T) / len(context)  # Shape: (1, embedding_dim)
                                                        # for every token in context

        # Update weights
        self.W1[[context]] -= self.learning_rate * dW1
        self.W2 -= self.learning_rate * dW2

setattr(Word2VecCBOW, 'backward', backward)

# %% [markdown]
# ##### 3.1.5 Training loop
#
# We need now a function that puts everything together and loops over all the training datapoints.

# %%
def train(self, training_idx, epochs=1000):
    for epoch in range(epochs):
        loss = 0
        for target, context in training_idx:
            # Forward pass
            h, y_pred = self.forward(context)
            
            # Compute loss (Cross-Entropy)
            loss -= np.log(y_pred[0, target])
            
            # Backward pass
            self.backward(context, target, h, y_pred)
        
        if epoch % 20 == 0:
            print(f"Epoch {epoch}, Loss: {loss:.4f}")

setattr(Word2VecCBOW, 'train', train)

# %% [markdown]
# Let's see if this works.

# %%
model = Word2VecCBOW(vocab_size, embedding_dim=10, learning_rate=0.01)
model.train(training_idx[:5], epochs=1000)
# Out:
# Epoch 0, Loss: 50.9574
# Epoch 20, Loss: 48.5345
# Epoch 40, Loss: 46.3283
# Epoch 60, Loss: 44.0996
# Epoch 80, Loss: 41.6337
# Epoch 100, Loss: 38.7152
# Epoch 120, Loss: 35.1323
# Epoch 140, Loss: 30.8845
# Epoch 160, Loss: 26.6534
# Epoch 180, Loss: 22.4198
# Epoch 200, Loss: 17.7739
# Epoch 220, Loss: 13.2793
# Epoch 240, Loss: 9.4265
# Epoch 260, Loss: 6.1363
# Epoch 280, Loss: 3.5561
# Epoch 300, Loss: 2.1842
# Epoch 320, Loss: 1.5957
# Epoch 340, Loss: 1.2912
# Epoch 360, Loss: 1.0991
# Epoch 380, Loss: 0.9631
# Epoch 400, Loss: 0.8599
# Epoch 420, Loss: 0.7779
# Epoch 440, Loss: 0.7106
# Epoch 460, Loss: 0.6540
# Epoch 480, Loss: 0.6057
# Epoch 500, Loss: 0.5638
# Epoch 520, Loss: 0.5271
# Epoch 540, Loss: 0.4946
# Epoch 560, Loss: 0.4657
# Epoch 580, Loss: 0.4397
# Epoch 600, Loss: 0.4163
# Epoch 620, Loss: 0.3951
# Epoch 640, Loss: 0.3758
# Epoch 660, Loss: 0.3581
# Epoch 680, Loss: 0.3419
# Epoch 700, Loss: 0.3269
# Epoch 720, Loss: 0.3131
# Epoch 740, Loss: 0.3003
# Epoch 760, Loss: 0.2884
# Epoch 780, Loss: 0.2774
# Epoch 800, Loss: 0.2671
# Epoch 820, Loss: 0.2574
# Epoch 840, Loss: 0.2484
# Epoch 860, Loss: 0.2399
# Epoch 880, Loss: 0.2319
# Epoch 900, Loss: 0.2244
# Epoch 920, Loss: 0.2173
# Epoch 940, Loss: 0.2106
# Epoch 960, Loss: 0.2043
# Epoch 980, Loss: 0.1983

# %% [markdown]
# The weight matrix $W_1$ contains our embeddings!
